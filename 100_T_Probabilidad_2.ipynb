# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Estadistica_Moderna/blob/main/100_T_Probabilidad_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Breves notas de Teoria de la Probabilidad**
#  - **Por Julio Hurtado Marquez**

# %% [markdown]
# # **10. Variables aleatorias**
#
# ### **$\bullet$** Recordemos que el espacio muestral $\Omega$, contiene todos los resultados posibles de un experimento.
# ### **$\bullet$** Para cada uno de estos posibles resultados, $\omega$, una variable aleatoria asigna un valor (generalmente numérico), es decir, una variable aleatoria, $X$, es realmente una función $X: \Omega \rightarrow \mathbb{R}$, o $X: \Omega \rightarrow \mathbb{R}^n$.
#
# ### **$\bullet$** La definición formal (es decir, desde el punto de vista de la teoría de la medida) de una variable aleatoria está dada por
#
#
# ## **10.1 Variable aleatoria**
#
# ### **$\bullet$**  ***Definición.***  Sea $(\Omega, \mathcal{F}, \mathbb{P})$ un espacio de probabilidad. Una **variable aleatoria** (v.a) es una función $X:\Omega\rightarrow \mathbb{R}$  tal que para cada $x\in\mathbb{R}$, se cumple que $\{\omega  \in \Omega: X(\omega) \leq x  \} \in \mathcal{F}$
#
# ### **$\bullet$** **Notación** $$
# \{\omega  \in \Omega: X(\omega) \leq x  \} = X^{-1}(]-\infty, x]) =\{X\leq x\}=(X\in(-\infty,x]))  \in \mathcal{F}, \ \mbox{para todo } x \in \mathbb{R}
# $$
#
# ### **$\bullet$** Se utilizará la siguiente notación $$
# \mathbb{P}\{X^{-1}(]\infty, x])\} :=\mathbb{P}\{X \leq x\}
# $$
# - de manera similar para los otros eventos.
#
#
#
# ## **10.2 Probabilidad inducida por la Variable aleatoria**
#
# ### **$\bullet$**  Sea $X$ una v.a definida sobre un espacio de probabilidad $(\Omega, \mathcal{F}, \mathbb{P})$. Para cada intervalo  $]\infty, x]\subseteq\mathbb{R}$, se define la función $$
# \mathbb{P_X}(]-\infty, x]) =\mathbb{P}(X\in]-\infty, x])=\mathbb{P}[X \leq x]
# $$
# ### **$\bullet$**  La condición de medibilidad en la definición de v.a garantiza que el conjunto$\{X\leq x\}=(X\in(-\infty,x]))  \in \mathcal{F}$ y por lo tanto puede aplicarse la función $\mathbb{P}$, de esta manera la función $\mathbb{P}_X$ está bien definida y pueda extenderse a una medida de probabilidad sobre $\mathcal{B}(\mathbb{R})$, así $$(\Omega, \mathcal{F}, \mathbb{P})\rightarrow (\mathbb{R}, \mathcal{B}(\mathbb{R}), \mathbb{P}_X)$$
#
#
#
# ## **$\bullet$**  **Ejemplo**
# ### **$\bullet$**  Sea E.A = "**Lanzamiento de una moneda equilibrada**"
# ### **$\bullet$**  Espacio Muestral: $\Omega =${**Cara**,**Sello**}
# ### **$\bullet$**  $\mathcal{F}=2^{\Omega}$
# ### **$\bullet$**  $$
# \mathbb{P}(\{Cara\})=\mathbb{P}(\{Sello\}) = \dfrac{1}{2}
# $$
# ### **$\bullet$**  Tomemos un Boreliano $\mathcal{B}\subseteq\mathbb{R}$
# ### **$\bullet$**  Sea $X: \Omega \rightarrow \mathbb{R}$,  definida así: $X(Cara)=0$ y $X(Sello)=1$
#
#
# ### **$\bullet$** $$
# \mathbb{P_X}(\mathcal{B}) =\mathbb{P}(X\in\mathcal{B})=0; \ 0\notin\mathcal{B}, \ 1\notin\mathcal{B}\\
# \mathbb{P_X}(\mathcal{B}) =\mathbb{P}(X\in\mathcal{B})=\dfrac{1}{2}; \ 0\in\mathcal{B}, \ 1\notin\mathcal{B}\\
# \mathbb{P_X}(\mathcal{B}) =\mathbb{P}(X\in\mathcal{B})=\dfrac{1}{2}; \ 0\notin\mathcal{B}, \ 1\in\mathcal{B}\\
# \mathbb{P_X}(\mathcal{B}) =\mathbb{P}(X\in\mathcal{B})=1; \ 0\in\mathcal{B}, \ 1\in\mathcal{B}$$
#
#
# ### **$\bullet$**  En forma de tabla
#
# |$X=x$|0|1|
# |:-:|:-:|:-:|
# |$P\{X=x\}$|$\dfrac{1}{2}$|$\dfrac{1}{2}$|

# %% [markdown]
# ## **10.3 Ejemplos**  Sea $\varepsilon$= "*Lanzar un dado equilibrado*"
# ### **$\bullet$** $\Omega = \{1, 2, 3, 4, 5,6\}$ *equiprobables*
# ### **$\bullet$** $\mathcal{F}=2^{\Omega}$
# ### **$\bullet$**$\mathbb{P}\{i\}=\dfrac{1}{6}$ para $i=1,2,\cdots,6$
# ### **$\bullet$** Sean las Variables aleatorias:
# ### **$\bullet$**- $X(\omega)=\omega\in\{1,2,3,4,5,6\}$
# ### **$\bullet$** $Y(\omega)=1, si \ \omega\in\{2,4,6\}$
# ### **$\bullet$** $Z(\omega)=5$
# ### **$\bullet$** Entonces:
# ### **$\bullet$**  $\mathbb{P}(X\in\{4,5\})=$
# ### **$\bullet$**$\mathbb{P}(Y=1)=$
# ### **$\bullet$**$\mathbb{P}(Z=0)=$
# ### **$\bullet$**$\mathbb{P}(Z=5)=$

# %% [markdown]
# ## **10.4 Ejemplos**  Sea $\varepsilon$= Lanzar un dardo dentro del cuadado $(-1,1)\times(-1,1)$
# ### **$\bullet$** $\Omega = (-1,1)\times(-1,1) =\{(x,y): -1<x,y<1\}$ *equiprobables*
# ### **$\bullet$** $\mathcal{F}= \{A|A\subseteq\Omega\}$
# ### **$\bullet$**$\mathbb{P}\{A\}=\dfrac{area(A)}{area(\Omega)}$
# ### **$\bullet$** Considere las Variables aleatorias y halle sus rangos:
# ### **$\bullet$** $X(\omega)=x$
# ### **$\bullet$** $Y(\omega)=y$
# ### **$\bullet$** $X+Y$
# ### **$\bullet$** $X^2$
# ### **$\bullet$** $5Y$
# ### **$\bullet$** $X+1$
# ### **$\bullet$** $Z(\omega)=\sqrt{x^2+y^2}$
# ### **$\bullet$** Entonces:
# ### **$\bullet$** $\mathbb{P}(X\in(a,b))=$
# ### **$\bullet$** $\mathbb{P}(Y=\dfrac{1}{2})=$
# ### **$\bullet$** $\mathbb{P}(Z\leq\dfrac{3}{4})=$
# ### **$\bullet$** $\mathbb{P}(Z\leq{r}r)=$

# %% [markdown]
# ## **11.0 Funciones de masa de probabilidad para Variables Aleatorias Discretas**
#
# ### **$\bullet$** Una variable aleatoria discreta con valores sobre el conjunto $\mathbb{R}$, es una función de $\Omega$ sobre un subconjunto finito o numerable infinito $\{x_1, x_2, \ldots\}$ de números reales, de tal manera que $\{\omega: X(\omega) = x_i \} \in \mathcal{F}$ para toda $i$.
#
# ### **$\bullet$** Cada variable aleatoria discreta, $X$, tiene asociada una función, $f$, llamada la *función de masa de probabilidad*.
#
# ### **$\bullet$** Sea $X$ una variable aleatoria discreta con valores en $\mathbb{R}$. Si $f$ es una función tal que:
# ### **$\bullet$** $f(x) = \mathbb{P}(X = x) \geq 0$ para todo $x \in \mathbb{R}$.
# ### **$\bullet$** El conjunto $A = \{x: f(x) \neq 0 \}$ es un subconjunto finito o numerable infinito de $\mathbb{R}$. $$\sum_{x \in A} f(x) = 1$$.
# ### **$\bullet$** Entonces decimos que $f$ es una función de densidad (o función de masa) de $X$.
#
#
#
# ### **11.1 Ejemplo**. Lanzamos una moneda $10$ veces. Sea $X(\omega)=:$ el número de caras en la secuencia $\omega$. Por ejemplo si $\omega = CCSCCSCCSS$, entonces $$X(\omega) = 6$$.
#
# ### **11.2 Ejemplo**. Sea $X$ la variable aleatoria con distribución
#
# |$x$|1|2|3|
# |:-:|:-:|:-:|:-:|
# |$f(x)$|$\dfrac{1}{4}$|$\dfrac{1}{2}$|$\dfrac{1}{4}$|
# ||||
#
# + Dada por
#
# $$f(x)= \left\{ \begin{array}{lcc}
#              \dfrac{1}{4} &   si  & x=1, \\
#              \\ \dfrac{1}{2} &   si  & x=2, \\
#              \\ \dfrac{1}{4} &   si  & x=3,  \\
#               \\ 0 &   en & otro & caso
#              \end{array}
#    \right.$$
#
#
# ### **$\bullet$** Entonces:
# ### **$\bullet$** * $\mathbb{P}(X\in[1,2])=$
# ### **$\bullet$** $\mathbb{P}(X\in[3,+\infty))=$
# ### **$\bullet$**$\mathbb{P}(X\in\{-1,0,1\})=$
#
#
# ### **11.3. Esperanza y varianza de una variable aleatoria discreta**
# ### **a. Valor Esperado**
# - Sea $X$ una variable aleatoria discreta con función de probabilidad $f(x)$: Entonces, se define  $$\mu =\mathbb{E}(X)=\sum_{x\in\Omega}xf(x)$$
#
# ### **b. Varianza**
# $$ \  \ y \ \ \mathbb{V}(X)=\sum_{x\in\Omega}(x-\mu)^2f(x)=\mathbb{E}(X^2)-\mu^2 $$
#
#
#
# ### **$\bullet$ Ejemplo.** Lancemos dos monedas y sea $X=:$ el número de caras. Entonces, $\mathbb{P}(X = 0) =\mathbb{P}(\{SS\}) = 1/4$, $\mathbb{P}(X = 1) = \mathbb{P}(\{ CS, SC\}) = 1/2$ y $\mathbb{P}(X = 2) = \mathbb{P}(\{CC \} ) = 1/4$. Las variables aleatorias y su distribución puede ser resumida como sigue:
#
# |$\{X=x\}$|0|1|2|
# |:--:|:--:|:--:|:--:|
# |$\mathbb{P}\{X=x\}$|$\dfrac{1}{4}$|$\dfrac{1}{2}$|$\dfrac{1}{4}$|
#
# ### **$\bullet$**  Hallar el $\mathbb{E}(X)$ y $\mathbb{V}(X)$
#
# ### **Ejemplo** Suponga que la variable aleatoria $X$ tiene distribución de probabilidad
#
# $$f(x)= \left\{ \begin{array}{lcc}
#              (\dfrac{1}{2})^x &   si  & x=1,2,\cdots, \\
#              \\ 0 &   en& otro&caso
#              \end{array}
#    \right.$$
#
# ### **$\bullet$** Hallar el $\mathbb{E}(X)$ y $\mathbb{V}(X)$
#
# $$\mu =\mathbb{E}(X)=\sum_{x\in\Omega}xf(x)=\sum_{x=1}^{\infty}x (\dfrac{1}{2})^x=1*(\dfrac{1}{2})^1+2*(\dfrac{1}{2})^2+3*(\dfrac{1}{2})^3+\cdots+\\=\sum_{x=1}^{\infty}[\sum_{y=1}^{x}1] (\dfrac{1}{2})^x=\sum_{y=1}^{\infty}[\sum_{x=y}^{\infty}(\dfrac{1}{2})^x] \\ =\sum_{y=1}^{\infty}\dfrac{(\dfrac{1}{2})^y-(\dfrac{1}{2})^{\infty}}{1-\dfrac{1}{2}}
# \\ =2\sum_{y=1}^{\infty}(\dfrac{1}{2})^y \\  =2\dfrac{(\dfrac{1}{2})^1-(\dfrac{1}{2})^{\infty}}{1-\dfrac{1}{2}} = 2
# $$
#
#
#
#
#
#
# $$\mathbb{E}(X^2)=\sum_{x\in\Omega}x^2f(x)=\sum_{x=1}^{\infty}x^2(\dfrac{1}{2})^x \\
# =1^2*(\dfrac{1}{2})^1+2^2*(\dfrac{1}{2})^2+3^2*(\dfrac{1}{2})^3+\cdots+\\
# =\sum_{x=1}^{\infty}[(x(x-1)+x)] (\dfrac{1}{2})^x \\
# =\sum_{x=1}^{\infty}[x(x-1) (\dfrac{1}{2})^x]+\sum_{x=1}^{\infty}x (\dfrac{1}{2})^x \\
# =2\sum_{x=1}^{\infty}[\sum_{y=1}^{x-1}y (\dfrac{1}{2})^x]+2 \\
# =2*\dfrac{1}{2}\sum_{x=1}^{\infty}[\sum_{y=1}^{x-1}y (\dfrac{1}{2})^{x-1}]+2 \\
# =\sum_{y=1}^{\infty}[\sum_{x=y}^{\infty}y (\dfrac{1}{2})^{x}]+2 \\
#  =\sum_{y=1}^{\infty}y\dfrac{(\dfrac{1}{2})^y-(\dfrac{1}{2})^{\infty}}{1-\dfrac{1}{2}}+2
# \\ =2\sum_{y=1}^{\infty}y(\dfrac{1}{2})^y +2\\  =2\mathbb{E}({X}) +2 = 2*2+2=6
# $$
#
# ### **$\bullet$** Por tanto, $$\sigma^2=\mathbb{E}(X^2)-\mu^2= 6-4 =2$$

# %% [markdown]
# #  **12.0 Distribuciones de Probabilidad Discreta mas comunes**
#
# ### **$\bullet$** **Uniforme Discreta**: $X\sim U(\{y_{1},y_{2}\dots,y_{n}\})$
# ### **$\bullet$** **Binomial**: $X\sim B(n,p)$
# ### **$\bullet$** **Geométrica**:  $X\sim G(p)$
# ### **$\bullet$** **Hipergeométrica**: $X\sim H(N,M,n)$
# ### **$\bullet$** **Binomial Negativa**: : $X\sim Bneg(r,p)$
# ### **$\bullet$** **Poisson**: $X\sim U(\lambda)$

# %% [markdown]
# # **13.0 La distribución de Probabilidad Uniforme Discreta**
# ### **$\bullet$** Supongamos que  $Y$ es una variable aleatoria discreta que toma valores en el conjunto $\{y_{1},y_{2}\dots,y_{n}\}$. Decimos que  $Y\sim U(\{y_{1},y_{2}\dots,y_{n}\})$, esto es, $Y$  tiene distribución uniforme discreta, si tiene función de probabilidad  $$P\{Y=y\}=1/n$$ paa $y = y_{1},y_{2}\dots,y_{n}$
# ### **$\bullet$** **Valor Esperado** $$E(Y) = \frac{1}{n} \sum_{j=1}^n y_j =\bar{y}=\frac{n+1}{2} $$.
#
# ### **$\bullet$** **Varianza** $$ V(Y) = \frac{1}{n} \sum_{j=1}^n (y_j - E(Y))^2 =\frac{n^2-1}{12}$$.
#
#
#
# ## **13.1 Ejemplo.**
# ### **$\bullet$** **Problema**. Suponga que se lanza un dado perfecto y se anota el número en la cara arriba del dado. Sea $X = num_cara$. Entonces, $X\sim U(\{1, 2\dots,6\})$. Calcular y graficar la pmf de $X$
#
# ### **$\bullet$** En forma de Tabla:
#
# |$\{X =x\}$|1|2|3|4|5|6|
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# |$f(x)=P\{X=x\}$|$\frac{1}{6}$|$\frac{1}{6}$|$\frac{1}{6}$|$\frac{1}{6}$|$\frac{1}{6}$|$\frac{1}{6}$|

# %% [markdown]
# ## **13.2 Usamos Python para simular el lanzamiento de un dado**

# %%
## **13.2 Usamos Python para simular el lanzamiento de un dado**
import numpy as np
import matplotlib.pyplot as plt

# X = Número en la cara arriba del dado
num_caras = 6

# Probabilidad para cada cara
probabilidad = 1 / num_caras

# Valores posibles de la variable aleatoria (caras del dado) X={1,2,3,4,5,6}
valores = np.arange(1, num_caras + 1)

# Crear un arreglo de probabilidades uniformes
probs_unifs = np.full(num_caras, probabilidad)

# Crear el gráfico de la distribución de probabilidad
plt.bar(valores, probs_unifs, tick_label=valores)
plt.xlabel('Cara del dado')
plt.ylabel('Probabilidad')
plt.title('Distribución de Probabilidad Uniforme para un Dado de 6 Caras')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# Imprimir las probabilidades
for cara, prob in enumerate(probs_unifs, 1):
    print(f"Cara {cara}: P({cara}) = {prob}")
# Out:
# Cara 1: P(1) = 0.16666666666666666
# Cara 2: P(2) = 0.16666666666666666
# Cara 3: P(3) = 0.16666666666666666
# Cara 4: P(4) = 0.16666666666666666
# Cara 5: P(5) = 0.16666666666666666
# Cara 6: P(6) = 0.16666666666666666

# %% [markdown]
# ## **13.3 Supongamos que lanzamos el dado diez mil veces y queremos saber si esas probabilidades se mantienen - Esto es la Ley de los grandes numeros**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Número de lanzamientos de dado
num_lanzamientos = 10000

# Simular lanzamientos de un dado perfecto (valores del 1 al 6)
lanzamientos = np.random.randint(1, 7, num_lanzamientos)

# Crear un histograma para mostrar la distribución
plt.hist(lanzamientos, bins=np.arange(0.5, 7.5, 1), alpha=0.75, density=True, rwidth=0.85)
plt.xlabel('Cara del dado')
plt.ylabel('Frecuencia relativa')
plt.title('Distribución de Lanzamientos de un Dado Perfecto')
plt.xticks(np.arange(1, 7, 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el histograma
plt.show()
