# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Estadistica_Moderna/blob/main/26_C_Probabilidad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Breves notas de Teoria de la Probabilidad**
#  - **Por Julio Hurtado Marquez**

# %% [markdown]
# # **1.0. Breve historia de la probabilidad - por Chat GPT**
# - La historia de la probabilidad es fascinante y abarca varios siglos de desarrollo. Aquí te presento un breve recorrido por los hitos más destacados en la evolución de la probabilidad:
#
# ## **1.1. Orígenes Antiguos**
# - Los primeros indicios de conceptos relacionados con la probabilidad se remontan a civilizaciones antiguas como los egipcios y los romanos, quienes utilizaban dados y otros juegos de azar. Sin embargo, estos enfoques iniciales estaban más relacionados con la práctica que con la teoría.
#
# ## **1.2. Cartas y Correspondencia:**
#
# + En el siglo XVI, los matemáticos italianos *Gerolamo Cardano* y *Girolamo Saccheri* realizaron contribuciones significativas al estudio de juegos de cartas y probabilidad. Cardano, en particular, escribió un libro titulado ***Liber de Ludo Aleae (El libro sobre los juegos de azar)***, en el que discutió conceptos de probabilidad.
#
# ## **1.3. Pascal y Fermat:**
# + En el siglo XVII, *Blaise Pascal* y *Pierre de Fermat* colaboraron en la resolución de problemas de juegos de azar que involucraban apuestas y probabilidades. Sus correspondencias dieron lugar a la formulación de lo que hoy se conoce como el Triángulo de Pascal y la Regla de Fermat-Pascal, herramientas fundamentales en la teoría de la probabilidad.
#
# ## **1.4. Laplace y la Probabilidad Clásica:**
# + A fines del siglo XVIII, ***Pierre-Simon Laplace***, un matemático y físico francés, contribuyó significativamente al desarrollo de la probabilidad clásica. Propuso la idea de que la probabilidad podría entenderse como una medida de la incertidumbre y formuló el Principio de Indiferencia, que se utilizó para asignar probabilidades a eventos.
#
# ## **1.5. Teoría de la Probabilidad Formal:**
# +  Durante el siglo XIX, la probabilidad comenzó a desarrollarse como una teoría formal, en parte gracias a los trabajos de matemáticos como ***Andrei Markov*** y ***Aleksandr Lyapunov***. Surgieron teoremas y conceptos fundamentales, como la ***Ley de los Grandes Números*** y el ***Teorema Central del Límite***, que sentaron las bases de la estadística moderna.
#
#
# ## **1.6. Siglo XX y la Revolución Estadística:**
# -  El siglo XX presenció una explosión en la teoría de la probabilidad y la estadística. Figuras destacadas como ***Ronald A. Fisher, Jerzy Neyman, Abraham Wald*** y otros contribuyeron significativamente al desarrollo de la estadística moderna y su aplicación en campos tan diversos como la ***biología, la economía y la ciencia de datos***.
#
# ## **1.7. Probabilidad en la Era de la Computación:**
# - Con el avance de la informática, la ***probabilidad*** se convirtió en una herramienta esencial en el _análisis de datos y la toma de decisiones_. La simulación Monte Carlo y técnicas de probabilidad bayesiana se volvieron cruciales en campos como la inteligencia artificial y la ciencia de datos.
#
# **En resumen, la historia de la probabilidad es una narrativa de progreso continuo a lo largo de los siglos, desde sus raíces en los juegos de azar hasta su papel central en la ciencia y la toma de decisiones en la era moderna. La probabilidad es ahora una disciplina esencial en matemáticas y estadísticas, con aplicaciones que abarcan una amplia gama de campos y sectores de la sociedad.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2.0. Actividades independientes**
# - **Veamos el video Teoría de la Probabilidad**
#   - [Veamos el video Teoría de la Probabilidad](https://www.youtube.com/watch?v=eUVWxvEK7TM&t=42s)
# -
#
# - **Actividad 1: Evaluación de Teoría de la Probabilidad**
#   - [Evaluación de Teoría de la Probabilidad](https://forms.gle/YezG31vM6BAFXY6BA/)

# %% [markdown]
# # **3.0 Tipos de Experimentos**
#
# - Existen dos tipos de fenómenos o experimentos en la naturaleza: los deterministas y los aleatorios.
#
# ## **3.1. Experimento determinista**
#
# - Es aquel que produce el mismo resultado cuando se le repite bajo las mismas condiciones.
#
# ##  **3.2 Experimento aleatorio**
# - Es aquel que, cuando se le repite bajo las mismas condiciones, el resultado que se observa no siempre es el mismo y tampoco es predecible.
#
# ##  **3.3 Clasifica los experimentos segun sean Deterministas o Aleatorios**
#
# ###  **a. Ejemplo 1**. Medir el volumen de un gas cuando la presión y la temperatura son constantes produce, teóricamente, siempre el mismo resultado.
#
# - ![Determinista](https://upload.wikimedia.org/wikipedia/commons/1/15/Boyles_Law_animated.gif){width=width height=height}
#
#
# ###  **b. Ejemplo 2**. Medir el angulo de un rayo de luz reflejado en un espejo resulta siempre en el mismo resultado cuando el angulo de incidencia es el mismo y el resto de las condiciones son constantes.
#
# ###  **c. Ejemplo 3**. Muchas otras leyes de la física son ejemplos de situaciones en donde, bajo idénticas condiciones iniciales, el resultado delexperimento es siempre el mismo.
#
#
# ###  **d. Ejemplo 4**. El lanzar una moneda al aire y observar la cara de la moneda que mira hacia arriba al caer.
#
# ###  **e. Ejemplo 5**. Registrar el numero ganador en un juego de lotería, son ejemplos cotidianos de experimentos aleatorios.

# %% [markdown]
# # **4.0. Actividades independientes**
# - **Veamos el video Tipos de Experimentos**
#   - [Veamos el video Tipos de Experimentos](https://youtu.be/huSkDf3UOCc)
# -
#
# - **Actividad 1: Evaluación de Tipos de Experimentos**
#   - [Evaluación de Tipos de Experimentos]( https://forms.gle/VqCBiiFHcvLB4A7v6/)

# %% [markdown]
# # **5.0. El espacio muestral de un experimento aleatorio $\Omega$**
#
# - Es el conjunto de todos los posibles resultados del experimento aleatorio y se le denota, generalmente, por la letra griega $$\Omega$$. A un resultado particular del experimento se le denota por la letra $$\omega$$.
#
# - El espacio muestral no es necesariamente único y su determinación depende de lo que desea observar o estudiar la persona que realiza el experimento aleatorio.
# -  Se usa también la letra $S$ para denotar al espacio muestral.
# - Llamaremos ***evento o suceso*** a cualquier subconjunto del espacio muestral. Los eventos se denotan por las primeras letras del alfabeto en mayúsculas: $$A, B, C, D, E, F, G, \dots$$
#
# ## **5.1 Veamos el video Espacio muestral de un experimento aleatorio**
#
# - [Video Espacio muestral de un experimento aleatorio](https://www.youtube.com/watch?v=fd5kmNUwVK4&t=58s)
#
#
# ## **5.2 Ejemplos de Espacio muestral de un experimento aleatorio**
#
# ###  **a. Ejemplo 1**. E.A: Lanzamiento de un dado y observar el número que aparece en la cara superior.
# - Espacio muestral es $\Omega=\{1, 2, 3, 4, 5, 6\}$
# - **Eventos**:  $A=\{2, 4, 6\}$ es un evento. $\sharp(\Omega)=6$ y  $\sharp(A)=3$
#
# ###  **b. Ejemplo 2**.  E.A:   Participar en una rifa de los números $\{1,2, \cdots, 100\}$
# - Espacio muestral: $\Omega_1=\{1, 2, 3, 4, 5, ..., 100\}$ con $\sharp(\Omega_1)=100$
# - o bien $\Omega_2=\{``GANAR", ``PERDER"\}$.  con  $\sharp(\Omega_2)=2$
#
# ###  **c. Ejemplo 3**. Considere el E.A:  Lanzamiento de una moneda balanceada.
# - El espacio muestral es $\Omega=\{``cara",``sello"\}=\{\textbf{C},\textbf{S}\}$ y   o bien $\Omega=\{``0", ``1"\}$. $\sharp(\Omega)=2$
#
# ###  **d. Ejemplo 4**.  *Considere el E.A:  Lanzamiento de un dado hasta que apaece un 6*
# - El espacio muestral es $$\Omega=\{(6),(1,6),(2,6),...,(5,6), (1,1,6),...,(1,5,6), (2,1,6), ...,(3,1,6),...\}$$ . $$\sharp(\Omega)=\infty$$
#
#
# ###  **e. Ejemplo 5**.  Considere el E.A:  Tiempo de espera hasta que ocurre un evento.
#
# - El espacio muestral es $$\Omega=\{0, 1, 2, 3, 4, 5, ...\}$$ y   o bien $$\Omega=[0,\infty), \ \sharp(\Omega)=\infty$$.
#
# ###  **f. Ejemplo 6**.  E.A:  *Lanzar un dado en un tablero circular de radio 1.*
#
# - Espacio muestral es $\Omega=\{(x,y) \mid x^2+y^2\leqslant1\}$    o bien $\Omega=\{(r,\theta) \mid 0\leq r\leq 1, 0\leq \theta\leq 2\pi\}$.
# - $\sharp(\Omega)=2\pi$
#
# ###  **g. Ejemplo 7**. Considere el E.A:  Consiste en lanzar un par de dados  **distinguibles**
# - El espacio muestral es $\Omega=\{(1,1),\cdots,(1,6),(2,1),\cdots,(2,6),(6,1),(6,6)\}$ . $\sharp(\Omega)=36$
#
# ###  **h. Ejemplo 8**.  Considere el E.A:  Consiste en lanzar un par de dados **no distinguibles**.
#
# - El espacio muestral es $\Omega=\{(1,1),\cdots,(1,6),(2,2),\cdots,(2,6),(3,3),\cdots,(3,6),(4,4),\cdots,(4,6),(5,5),(5,6),(6,6)\}$. $\sharp(\Omega)=21$.
#
#
# ###  **i. Ejemplo 9**. Considere el E.A:  Lanzar un dado y luego tirar una moneda tantas veces como indicó el dado.
# - El espacio muestral es $$\Omega = \{(1C),(1S),(2CC),\cdots,(2SS),\cdots,(6CCCCCC),\cdots,(6SSSSSS)\}$$ .
# - $$\sharp(\Omega)=2^1+2^2+2^3+...+2^6=126$$.
#
#
# ###  **j. Ejemplo 10**.  Suponga que se lanzan dos dados y la moneda el total de veces que dicen los dados. ¿Cuántos resultados hay?
#
#
# |Resultado|Total|frecuencia|Total moneda|Total|
# |:-:|:-:|:-:|:-:|:-:|
# |(1,1)|2|1|$2^2=4$|1*4=4|
# |(1,2), (2,1)|3|2|$2^3=8$|2*8=16|
# |(1,3), (2,2), (3,1)|4|3|$2^4=16$|3*16=48|
# |(1,4), (2,3), (3,2), (4,1)|5|4|$2^5=32$|4*32=128|
# |(1,5), (2,4), (3,3), (4,2), (5,1)|6|5|$2^6=64$|5*64=320|
# |(1,6), (2,5), (3,4), (4,3), (5,2), (6,1)|7|6|$2^7=128$|6*128=768|
# |(2,6), (3,5), (4,4), (5,3), (6,2)|8|5|$2^8=256$|5*256=1280|
# |(3,6), (4,5), (5,4), (6,3)|9|4|$2^9=512$|4*512=2048|
# |(4,6), (5,5), (6,4)|10|3|$2^{10}=1024$|3*1024=3072|
# |(5,6), (6,5)|11|2|$2^{11}=2048$|2*2048=4096|
# |(6,6)|12|1|$2^{12}=4096$|1*4096=4096|

# %% [markdown]
# # **6.0 Eventos o sucesos**
# ### ***Definición***. Consideremos un E.A y sea $\Omega$ el espacio muestral asociado a éste experimento. Un subconjunto $A$, $A\subseteq\Omega$ se llama evento o suceso y nos referiremos a él como el evento o suceso $A$ ocurre, y su complementos $\overline{A}$ como el evento o suceso $A$ no ocurre.
#
# ## **6.1 Operaciones con Eventos o sucesos**
#
# - Si $A$ y $B$ son dos eventos de un espacio muestral $\Omega$ de un experimento aleatorio.
#
# ###  **a. Unión de Eventos**.
#
# - La Unión $${A \cup B=\{\omega\in \Omega \mid \omega\in A \vee \omega\in B \}}$$  lo cual se lee: $A\cup B$   ocurre si $A$ ocurre ó $B$ ocurre.
# + Tambien se lee "Almenos uno de los eventos ocurre"
#
# ###  **b. Intersección de Eventos**.
# - La Intersección $${A \cap B =\{\omega\in \Omega \mid \omega\in A \wedge \omega\in B \}}$$  lo cual se lee: $A\cap B$ ocurre si $A$ ocurre y $B$ ocurre.
#
# ###  **c. Diferencia de Eventos**.
# - La Diferencia $$A - B=\{\omega\in \Omega \mid \omega\in A \wedge \omega\not \in B \}$$ lo cual se lee: ``Sólo ocurre $A$´´. - También $A - B=A\cap\overline{B}$
# - La Diferencia, $B - A=\{\omega\in \Omega \mid \omega\in B \wedge \omega\not \in A \}$ , lo cual se lee: ``Sólo ocurre $B$´´.
# - También $B - A=B\cap\overline{A}$.
#
# ###  **d. Diferencia Simétrica de Eventos**.
#  - La Diferencia simétrica $$A \bigtriangleup B=(A - B)\cup(B-A)$$  lo cual se lee: ``{Exáctamente ocurre uno}".
#  - Complemento, $\overline{A}=\Omega -A$ , lo cual se lee: "*No ocurre* $A$".
#
# ###  **e. Leyes de Morgan**.
# - Complemento de la Unión: $${\overline{A \cup B}}={\overline{A} \cap \overline{B}}$$  lo cual se lee: ***ninguno ocurre***
# - Complemento de la Intersección: $$\overline{A \cap B}=\overline{A} \cup \overline{B}$$ lo cual se lee: ***`almenos uno no ocurre***, o bien, ***no todos ocurren***.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##  **6.2. Propiedades de los Eventos**. Sean $A$, $B$, $C$ tres eventos en un espacio muestral $\Omega$ de un experimento aleatorio.
# - ***Unión***
#   - $A \cup B= B \cup A$
#   -  ${A \cup A = A}$
#   -  ${A \cup \varnothing= A}$
#   -  ${A \cup \Omega= \Omega}$
#
# - ***Intersección***
#   -   ${A \cup \overline{A}= \Omega}$
#   -   ${A \cap B= B \cap A}$
#   -   ${A \cap A= A}$
#   -  ${A \cap \varnothing= \varnothing}$
#   -  ${A \cap \Omega= A}$
#   -   ${A \cap \overline{A}= \varnothing}$
# - ***Diferencias***
#   -   ${A - B \not = B - A}$
#   -     ${A - A= \varnothing}$
#   -    ${A - \varnothing= A}$
#   -    ${\Omega - A  = \overline{A}}$
#   -    ${A - B= A - (A \cap B)}$
#
# - ***Complementos***
#   -     ${\overline{\varnothing}=\Omega}$
#   -     ${\overline{\Omega}= \varnothing}$
#   -     ${\overline{\overline{A}}=A}$
#   -     ${A \cup (B \cup C)=(A \cup B) \cup C}$
#   -     ${A \cup (B \cup C)=A \cup B \cup C}$
#   -     ${A \cap (B \cap C)=(A \cap B) \cap C}$
#   -     ${A \cap (B \cap C)=A \cap B \cap C}$
#   -     ${A \cap (B \cup C)=(A \cap B) \cup (A \cap C)}$
#   -     ${A \cup (B \cap C)=(A \cup B) \cap (A \cup C)}$
#
#
# ##  **6.3. Propiedades de las sucesiones de Eventos**.
#
# - Sean $B_1, B_2,\cdots, B_n,\cdots$, una sucesión eventos en un espacio muestral $\Omega$ de un experimento aleatorio.
#
# - Unión finita: ${\displaystyle\bigcup_{k=1}^{k=n}{B_k }}$
# - Unión infinita: ${\displaystyle\bigcup_{k=1}^{\infty}{B_k }}$. Lo cual se lee {ocurre almenos uno de los eventos}
# - Intersección infinita: ${\displaystyle\bigcap_{k=1}^{k=n}{B_k }}$
# - Intersección infinita: ${\displaystyle\bigcap_{k=1}^{\infty}{B_k }}$. Lo cual se lee {ocurren todos los eventos}
#
# - Unión : ${A \cup (\displaystyle\bigcup_{k=1}^{\infty}{B_k })=\displaystyle\bigcup_{k=1}^{\infty}{(A \cup B_k) }}$
#
# - Intersección: ${A \cap (\displaystyle\bigcap_{k=1}^{\infty}{B_k })=\displaystyle\bigcup_{k=1}^{\infty}{(A \cap  B_k)}}$.
#
# - Leyes de Morgan: ${\overline{\displaystyle\bigcup_{k=1}^{\infty}{B_k }}=\displaystyle\bigcap_{k=1}^{\infty}\overline{{B_k }}}$.
#
# - Leyes de Morgan: ${\overline{\displaystyle\bigcap_{k=1}^{\infty}{B_k }}=\displaystyle\bigcup_{k=1}^{\infty}\overline{{B_k }}}$.
#
# ##  **6.4. Conjunto potencia**.
#
# - Sea $\Omega \not =\varnothing$ un conjunto.
# - El conjunto que contiene a todos los subconjunto $A$ de $\Omega$ se llama conjunto potencia y se denota $$\wp(\Omega)=2^\Omega =\{A \mid A\subseteq \Omega\},$$
#
# - Si $\Omega<\infty$, se cumple que $$\sharp(2^\Omega)=2^{\sharp(\Omega)}$$
#
#
# ###  **Ejemplo**:
# - Si $\Omega  =\{a,b,c \}$, $$2^\Omega =\{\varnothing, \{a\}, \{b\}, \{c\}, \{a,b\},\{a,c\},\{b,c\}, \Omega\}$$
# - $\sharp(2^\Omega)= 2^3 =8$

# %% [markdown]
# ## **6.5 Producto cartesiano entre dos conjuntos**.
#
# - El producto cartesiano entre dos conjuntos $A$ y $B$ viene dado por $A \times B =\{(x,y) \mid x \in A, y \in B \}$
#
# ###  **a. Ejemplo** Sean $A =\{0,1\}$ y $B =\{x,y\}$. Entonces,
# + $A \times B =\{(0,x),(0,y),(1,x),(1,y) \}$
# - Análogamente se define ${A_1\times A_2\times\cdots\times A_n}$
#
# ###  **a. Propiedades del producto cartesiano**
# - $A \times B \not =B \times A$
# - Si $\sharp(A) =m$ y $\sharp(B) =n$, entonces,  $\sharp (A \times B ) =mn$
# - $\sharp(A \times B) =\sharp(B \times A)$
# - ${\sharp({A_1\times A_2\times\cdots\times A_k)=n_1 n_2\cdots n_k}}$
#
# ###  **c. Ejemplo**
# - ${\mathbb{R}^{2} =\mathbb{R}\times \mathbb{R}=\{(x,y) \mid x \in \mathbb{R}, y \in \mathbb{R} \}}$.
# - ${\mathbb{R}^{n} =\mathbb{R}\times\cdots\times \mathbb{R}=\{(x_1,\cdots,x_n) \mid x_1 \in \mathbb{R},\dots, x_n \in \mathbb{R} \}}$.
#
# ## **6.6 Eventos mutuamente excluyentes**
# - Sean $A$, $B$ eventos en un espacio muestral $\Omega$ de un experimento aleatorio. Como conjuntos $A$ y $B$ son ajenos o disjuntos o como eventos son mutuamente excluyentes si ${A \cap B= \varnothing}$
#
# - $A_1,A_2,\dots,A_n$ son mutuamente excluyentes si ${A_1\cap A_2\cap \dots\cap A_n=\varnothing}$
# - $A_1,A_2,\dots,A_n$ son mutuamente excluyentes dos a dos si ${A_i\cap A_j=\varnothing}$, para ${i\not=j;i,j=1,\dots,n}$
# - Una colección infinita de eventos $A_1,A_2,\dots,A_n,\dots,$ son *mutuamente excluyentes dos a dos* si cualquier subconjunto finito de ella tambien lo es.
#
#
# ## **6.7 Partición de Eventos**
#
# - Se dice que los conjuntos $A_{1},A_{2},A_{3},\ldots,A_{n}$ forman una partición o un sistema completo de sucesos, si son disjuntos dos a dos y la unión de todos ellos es el conjunto universal, es decir:
#
# - $A_{i} \cap A_{j} = \emptyset \quad \forall i \neq j$
#
# - $A_{1} \cup A_{2} \cup A_{3} \cup \cdots \cup A_{n}= \Omega$

# %% [markdown]
# #  **7.0 Álgebras y Sigma álgebras**
# ##  **7.1 Álgebras**
#
# - Una familia $\cal A$ de subconjuntos de $\Omega$  tiene estructura de  Álgebra o Álgebra de Boole sobre
# $\Omega$, si verifica:
#
#   -  $\Omega \in \cal A$
#   -  $\forall A, B \in {\cal A} \Rightarrow A \cup B \in {\cal A}$
#   -  $\forall A \in {\cal A} \Rightarrow \bar{A} \in {\cal A}$
#
# - El par $(\Omega,\cal A)$ se dirá espacio medible finito o Espacio medible finito.
#
#
#
# ##  **7.1 Sigma álgebra**
#
# #####  **Definción**
# - Una colección, $\mathcal{F}$, no vacía de subconjuntos de un conjunto $\Omega$, se llama una *sigma álgebra* ($\sigma$-álgebra) si cumple las siguientes propiedades:
#
# - $\Omega \in \mathcal{F}$.
# - Si $A \in \mathcal{F}$, entonces $A^{c} \in \mathcal{F}$.
# - Si $A_n \in \mathcal{F}$, $n = 1,2, \ldots$, entonces $$\displaystyle\bigcup_{n=1}^{\infty}A_n \in \mathcal{F}$$ y $$\displaystyle \bigcap_{n=1}^{\infty}A_n \in \mathcal{F}$$.
# - De acuerdo a la definición, podemos restringir nuestra atención únicamente a los eventos que pertenecen a una sigma álgebra.
#
# ##  **7.2 Ejemplos de σ-álgebras**.
#
# ###  **a. Ejemplo. σ-álgebra de Borel en la recta real**: En $\mathbb{R}$ (la recta real), la ***σ-álgebra de Borel*** es una σ-álgebra que contiene todos los conjuntos abiertos, cerrados y semiabiertos. También contiene todos los intervalos abiertos, semicerrados y cerrados. Es una σ-álgebra fundamental en análisis real y teoría de la medida.
#
# ###  **b. Ejemplo. σ-álgebra discreta**: En un conjunto finito o infinito numerable, la σ-álgebra discreta contiene todos los subconjuntos posibles. Si tienes un conjunto $X = \{x_1,x_2,...,x_n\}$, la σ-álgebra discreta consiste en todos los subconjuntos posibles de $X$, incluyendo el conjunto vacío y $X$ mismo.
#
# ###  **c. Ejemplo. σ-álgebra trivial**: La σ-álgebra trivial en cualquier conjunto $X$  contiene solo dos conjuntos: el conjunto vacío y $X$ mismo. Es la σ-álgebra más pequeña posible.
#
# ###  **d. Ejemplo. σ-álgebra de Lebesgue**: En $\mathbb{R}$, la σ-álgebra de Lebesgue es una σ-álgebra que contiene una amplia variedad de conjuntos, incluyendo todos los conjuntos de medida nula y sus complementos. Es fundamental en la teoría de la medida y la integración.
#
# ###  **e. Ejemplo. σ-álgebra de eventos en un espacio muestral**: En teoría de la probabilidad, en un espacio muestral dado $S$, la σ-álgebra de eventos es la colección de todos los subconjuntos de $S$ que son eventos medibles. Por ejemplo, en el lanzamiento de un dado, la σ-álgebra de eventos incluiría todos los eventos posibles relacionados con los resultados del dado.
#
# ###  **f. Ejemplo. σ-álgebra generada por una colección de conjuntos**: Dada una colección arbitraria de conjuntos, puedes construir una σ-álgebra generada por esos conjuntos. Esta σ-álgebra contendrá todos los subconjuntos que se pueden formar a partir de la colección original y será la más pequeña que los contenga.
#
# ### ***Estos son solo algunos ejemplos de σ-álgebras en diferentes contextos matemáticos. Las σ-álgebras son esenciales en la teoría de la medida, la probabilidad y otros campos matemáticos relacionados, ya que proporcionan una estructura para definir y manejar eventos medibles y conjuntos de manera coherente***.

# %% [markdown]
# # **7.0 Probabilidad**
#
# ## **7.1 Acerca de la definición de Probabilidad**
# - Continuando con el estudio de un experimento aleatorio y una vez que se han definido los sucesos, se aprecia la necesidad de definir alguna medida que cuantifique la incertidumbre de que un determinado suceso se obtenga al realizar un experimento
# aleatorio, a tal medida se le denomina **Probabilidad**
#
# - La dificultad de dar una definición del concepto de probabilidad sin objeciones o limitaciones, queda reflejada por los diferentes intentos realizados a lo largo de la historia para encontrar una definición de dicho concepto.
#
# - De la introducción histórica que se ha elaborado se desprende la existencia de tres definiciones del concepto de probabilidad que a continuación  se  discuten
#
# ## **7.2 Definición clásica (Laplace)**.
# - La probabilidad de un suceso $A$ es el cociente entre el número de casos favorables al suceso y el número de casos posibles.
#
# $$ P(A)=\frac{\sharp (A)}{\sharp (\Omega)} $$
# - Los inconvenientes de definir la probabilidad de esta forma son:*No es válida cuando los sucesos elementales no son equiprobables*, *A veces no es posible contar*.
#
#
#
# ## **7.3 Definición frecuentista (Bernouilli)**
# - La probabilidad de un suceso es el valorlímite de su frecuencia relativa al repetir indefinidamente la experimentación.
#
# - Sea $\Omega$ un espacio muestral y $\mathcal{F}$ una $\sigma$-álgebra de subconjuntos de $\Omega$.
# \item La probabilidad de un evento $A \in \mathcal{F}$, está dada por el límite
#
# $$
# \mathbb{P}(A) = \lim_{n \rightarrow \infty} \dfrac{n_A}{n}
# $$
# - en donde $n$ es el número total de ensayos y $n_A$ es el número de veces que ocurre el evento $A$.
# - Los inconvenientes de definir así la probabilidad son los siguientes:
# - Desde el punto de vista del análisis no puede interpretarse el límite anterior por la imposibilidad de fijar el número de repeticiones.
# - En algunas ocasiones no es posible realizar una experimentación indefinida.
# - Las condiciones bajo las cuales se realiza la experimentación pueden variar a lo largo del tiempo y, con ellas, las frecuencias relativas.
#
# - En la práctica, la definición de probabilidad frecuentista se encuentra limitada debido al hecho de que en la realidad $n$ y $n_A$ son números finitos y por lo tanto, lo que realmente se tiene es la aproximación
#
# $$
# \mathbb{P}(A) \approx \lim_{n \rightarrow \infty} \dfrac{n_A}{n}
# $$
#
# ## **7.4 Definición Axiomática (Kolmogórov)**
#
# - Para evitar los inconvenientes de ambas definiciones, además de un gran número de paradojas y dificultades surgidas a comienzos del presente siglo, se hizo necesaria una profunda revisión del concepto de probabilidad utilizando las herramientas más precisas del momento: *La teoría de conjuntos*, desarrollada principalmente por *Émile Borel (1871 -1956)*, y la potente **Teoría de la medida** debida a *Lebesgue - Henri Léon Lebesgue(1875 -1941)*
#
# - Todo lo anterior llevó a Andréi Kolmogórov a introducir axiomáticamente el concepto de Probabilidad.
#
#
# - Una medida de probabilidad $\mathbb{P}$, definida sobre elementos de una $\sigma$-álgebra $\mathcal{F}$ de subconjuntos de un conjunto $\Omega$, es una función $\mathbb{P}:\mathcal{F} \rightarrow [0,1]$ que cumple lo siguiente:
#
# - $\mathbb{P}(\Omega) = 1$.
# - $\mathbb{P}(A) \geq 0$ para todo $A \in \mathcal{F}$.
# - Si $A_n$, $n=1,2,\ldots$ son eventos mutuamente excluyentes es decir, se tiene que  $A_i \cap A_j = \emptyset$ para $i \neq j$, entonces
#
# $$
# \mathbb{P}\left(\displaystyle \bigcup_{n=1}^{\infty}A_n \right) = \sum_{n=1}^{\infty}\mathbb{P}(A_n)
# $$
#
# ## **7.5 Propiedades de la medida de probabilidad**
#
# ### **Teorema.**  Sea $\left( \Omega, \mathcal{F}, \mathbb{P} \right)$ un espacio de probabilidad. La medida $\mathbb{P}$ tiene las siguientes propiedades:
# ### **a.**   Para cualesquiera eventos $A,B$, $$\mathbb{P}(B) = \mathbb{P}(A \cap B) + \mathbb{P}(A^c \cap B)$$ (demostrar, sugerencia $\Omega = A \cup A^c $).
#
# ### **b.**    $\mathbb{P}(A^c) = 1 - \mathbb{P}(A)$,
# - en particular $\mathbb{P}(\emptyset) = 1 - \mathbb{P}(\Omega)$ (demostrar, sugerencia utilizar el punto anterior).
#
# ### **c.**    Si $A \subset B$, entonces $\mathbb{P}(B) \geq \mathbb{P}(A)$ (demostrar).
#
#
# ### **d.**    Sean $A_1, A_2, \ldots, A_n$  eventos, entonces,  $$\mathbb{P}(\bigcup_{i=1}^{n}A_i)  = \sum_{i=1}^{n}\mathbb{P}(A_i) - \sum_{1 \leq i < j \leq n} \mathbb{P}(A_i \cap A_j) +  \sum_{1 \leq i < j < k \leq n} \mathbb{P}(A_i \cap A_j \cap A_k) -  \ldots + (-1)^{n + 1}\mathbb{P}(A_1 \cap A_2 \cap \ldots \cap A_n)$$
#
#
# ### **Consecuencias de la definición**
# ### **a.**
# $$
# \mathbb{P}(A \cup B) = \mathbb{P}(A) + \mathbb{P}(B) - \mathbb{P}(A \cap B)
# $$
# ### **b.**     La probabilidad de la unión de sucesos incompatibles es igual a la suma de las probabilidades de cada uno de ellos,
# $$\forall \{A_i\}_{i\in \mathbb{N}} \mid A_i\cap A_j = \emptyset, \forall i \neq j, \qquad \mathbb{P}( \bigcup_{i\in N} A_i) = \sum_{i\in N} \mathbb{P}(A_i)$$
# ### **Observación**. El gran inconveniente de estas definiciones es que no dan un método para el cálculo de probabilidades, por lo que en la práctica hay que basarse en las  definiciones clásica y frecuentista.**
# ### **c.**     La probabilidad de ocurrencia del evento *no ocurre* $A$ denotado por $\bar{A}$ es
# $$\mathbb{P}(\bar{A}) = 1 - \mathbb{P}(A)$$
#
# ### **d.**     La probabilidad del suceso imposible es cero,
# $$\mathbb{P}(\emptyset) = 0$$
#
# ### **e.**     Si $A$ y $B$ son dos sucesos cualesquiera se verifica que:
# $$\mathbb{P}(A \cup B) = \mathbb{P}(A) + \mathbb{P}(B) - \mathbb{P}(A \cap B)$$
#
# ### **f.**     $$\mathbb{P}(A \cup B \cup C ) =\mathbb{P}(A) + \mathbb{P}(B) + \mathbb{P}(C)
# - \mathbb{P}(A \cap B) - \mathbb{P}(A \cap C) -\mathbb{P}(B \cap C)
# + \mathbb{P}(A \cap B \cap C)$$
#
#
# ## **7.6 Veamos el Video Probabilidad Parte 1**
# - [Video Probabilidad Parte 1](https://www.youtube.com/watch?v=u8695ip7Tww&t=35s)

# %% [markdown]
# #  **8.0 Probabilidad condicional**
# - Probabilidad de que  ***ocurra $A$***  si ***$B$ ya ocurrió*** denotado por $$\mathbb{P}(A\mid B),$$ viene definida por el cociente:
# $$\mathbb{P}(A\mid B) = \frac {\mathbb{P}(A \cap B)} {\mathbb{P}(B)}$$
# -  Análogamente, se define la probabilidad condicionada de $B$ respecto a $A$.
#  $$\mathbb{P}(B\mid A) = \frac {\mathbb{P}(A \cap B)} {\mathbb{P}(A)}$$
# - Utilizando conjuntamente ambos resultados se obtiene que:
#     $$\mathbb{P}(A \cap B) = \mathbb{P}(A\mid B)\mathbb{P}(B) = \mathbb{P}(B\mid A)\mathbb{P}(A)$$
#
#
# ###  **8.1 Ejemplo** El 60% de los alumnos de una clase de Estadística son chicas    y se sabe que el 30\% de las chicas son rubias. ¿Cuál es la probabilidad de escoger un alumno de la clase que sea chica y rubia?
# - Para resolver este ejemplo  se consideran los siguientes sucesos:
#
# - $F$=\{ser de sexo femenino}\}
# - $M$  =\{ser de sexo masculino\}
# - $R$  =\{tener pelo rubio\}.
#    $$\mathbb{P}(R \cap F)=\mathbb{P}(R\mid F) \mathbb{P}(F)=0.3\cdot 0.6=0.18$$
#
#
#
# ## **8.2 Función probabilidad condicional**.
# #### Si $\mathbb{P}(B)>0$, entonces $\mathbb{P}(\cdot \mid B)$ es una probabilidad:
# ###  **a.**  $\mathbb{P}(A\mid B) \geq 0 \quad \forall A$
#
# ###  **b.** $\mathbb{P}( \Omega \mid B ) = 1$
#
# ###  **c.** Para cualquier sucesión de sucesos disjuntos $\{A_i\}_{i=1}^{n/\infty}$, se
# verifica:
#  $$\mathbb{P}(\bigcup_{i=1}^{n/\infty} A _i \mid B) = \sum_{i=1}^{n/\infty} \mathbb{P}(A _i\mid B)$$
#
# ###  **d.** Dados $n$ sucesos, $A_1, A_2,\ldots,A_n$, se tiene:
# $$ \mathbb{P}(A _1 \cap A _2 \cap...\cap A _n)=\mathbb{P}(A _1)\cdot \mathbb{P}(A _2\mid A _1)\cdot \mathbb{P}(A _3\mid  A _1 \cap A _2)\cdot\ldots\ldots\cdot \mathbb{P}(A _n\mid A _1 \cap A _2 \cap...\cap A _{n-1})$$
#
#
# ## **8.3 Regla de la Probabilidad Total**
# ### Se considera un experimento que se realiza en dos etapas, en la primera se supone que los posibles sucesos, $A_1, A_2,\ldots,A_n$, constituyen un sistema completo, de tal forma que son conocidas las *probabilidades a priori*, $\mathbb{P}(A_1), \mathbb{P}(A_2),\ldots,\mathbb{P}(A_n)$.
#
# ### Si se conocen las probabilidades condicionadas $\mathbb{P}(B\mid A_i)$ para un cierto suceso $B$ y cada $A_i$ se verifica que:    $$\mathbb{P}(B)= \sum _{i=1} ^n \mathbb{P}(B\mid A _i)\mathbb{P}(A _i)$$
#
#
#
# # **8.4 Teorema de Bayes**
# ### Si conocemos que un suceso esperado $B$ ha ocurrido, nos podríamos preguntar por la probabilidad de ocurrencia de aquellos eventos que positivamente hubiesen originado la ocurrencia de $B$. Tal cálculo es posible usando una expresión que se conoce como la **fórmula de Bayes**
# ### $$
# \mathbb{P}(A_i|B) = \dfrac{\mathbb{P}(A_i) \mathbb{P}(B|A_i) }{\sum_{j=1}^{k} \mathbb{P}(A_j) \mathbb{P}(B|A_j)}
# $$
#
# ### El teorema de Bayes resuelve esta cuestión, llevando el cálculo de las probabilidades a un terreno más natural, expresando las  probabilidades a posteriori $\mathbb{P}(A_i|B)$ en función de las  **verosimilitudes** $\mathbb{P}(B|A_i)$.
#
#
# ### **Ejemplo**. - En una determinada ciudad se ha cometido un asesinato. De la investigación se encarga un detective, que tiene 5 sospechosos entre los que se encuentra el asesino. Se sabe que el detective trabaja con un pequeño margen de error, de forma que la probabilidad de creer inocente al verdadero asesino es de 0.05 y la probabilidad de creer culpable a una persona inocente es de 0.08. Si el detective cree que una persona es culpable, ¿cuál es la probabilidad de que esa persona sea el asesino?
# ### **Solución**. Para la resolución del problema se definen los siguientes sucesos:
#
# ### $A=$ \{ser asesino\}
# ### $I=$ \{ser enjuiciado inocente\}
# ### $C=$ \{ser enjuiciado culpable\}
#
# ### De esta forma se tiene que:
# ### *(a)* Hay un asesino de 5 sospechosos, por tanto, la probabilidad de que una persona elegida al azar sea el asesino es:
# $$\mathbb{P}(A)=\dfrac{1}{5} \quad \quad \mathbb{P}(\bar{A})=\dfrac{4}{5}$$
#
# ### *(b)* La probabilidad de creer inocente al verdadero asesino, es la probabilidad de ser enjuiciado inocente condicionada a que es el asesino, es decir, $\mathbb{P}(I|A)=0.05$. Además, se sabe que $\mathbb{P}(C|A)=1-P(I|A)=0.95$.
#
# ### *(c)* La probabilidad de creer culpable a una persona inocente, es la probabilidad de ser enjuiciado culpable condicionada a que no es el asesino, es decir, $\mathbb{P}(C| \bar{A})=0.08$.
#
#
# ### *(d)* En el problema se pide la probabilidad de que una persona asesina haya sido enjuiciada culpable, es decir, la probabilidad de que una persona sea asesina condicionada a que ha sido enjuicida culpable. Por tanto, la probabilidad requerida es $\mathbb{P}(A|C)$, para calcular dicha probabilidad se recurre al *teorema de Bayes*
# ### $$\mathbb{P}(A|C)=\dfrac{\mathbb{P}(C|A)\mathbb{P}(A)}{\mathbb{P}(C|A)\mathbb{P}(A)+\mathbb{P}(C|\bar{A})\mathbb{P}(\bar{A})}=\dfrac{0.95\cdot 0.2}{0.95\cdot 0.2 +0.08 \cdot 0.8}
# =\dfrac{0.19}{0.254}=0.748$$
#
#
# #  **9.0 Independencia de eventos**
# ### Una colección de eventos $A_1, \ldots, A_n$ se dice que es *mutuamente independiente* si para cada $k,\ 1 \leq k \leq n$, y cualesquiera $k$ eventos, $A_{i_1}, \ldots A_{i_k}$, se tiene que $$\mathbb{P}(A_{i_1} \cap \ldots A_{i_k}) = \mathbb{P}(A_{i_1}) \times \ldots \times \mathbb{P}(A_{i_k})$$.
#
# ### En particular, dos eventos son independientes si $$
# \mathbb{P}(A \cap B) = \mathbb{P}(A)\mathbb{P}(B)
# $$
#
# ### Utilizando la probabilidad condicional, para dos eventos independientes tenemos que $$
# \mathbb{P}(B|A) = \dfrac{\mathbb{P}(A \cap B)}{\mathbb{P}(A)} = \mathbb{P}(B)
# $$
