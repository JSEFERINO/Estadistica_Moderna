# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Estadistica_Moderna/blob/main/67_Series_Tiempo6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso Introductorio a la Ciencia de Datos por Julio Hurtado Márquez**
# ## **1. Aprendiendo - Series de Tiempo - Python**

# %% [markdown]
# # **a. instalar y importar las librerias**

# %%
# **a. instalar y importar las librerias**
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # **b. Cargar los datos, _parse_dates=True_ por ser una serie temporal**

# %%
# **b. Cargar los datos,# parse_dates=True por ser una serie temporal**
air_quality = pd.read_csv("/content/air_quality_no2.csv", index_col=0, parse_dates=True)
air_quality
# Out:
#                      station_1  station_2  station_3
# datetime
# 2019-05-07 02:00:00        NaN        NaN       23.0
# 2019-05-07 03:00:00       50.5       25.0       19.0
# 2019-05-07 04:00:00       45.0       27.7       19.0
# 2019-05-07 05:00:00        NaN       50.4       16.0
# 2019-05-07 06:00:00        NaN       61.9        NaN
# ...                        ...        ...        ...
# 2019-06-20 22:00:00        NaN       21.4        NaN
# 2019-06-20 23:00:00        NaN       24.9        NaN
# 2019-06-21 00:00:00        NaN       26.5        NaN
# 2019-06-21 01:00:00        NaN       21.8        NaN
# 2019-06-21 02:00:00        NaN       20.0        NaN
#
# [1035 rows x 3 columns]

# %% [markdown]
# # **c. Ver los 5 primeros datos**

# %%
# **c. Ver los 5 primeros datos**
air_quality.head()
# Out:
#                      station_1  station_2  station_3
# datetime
# 2019-05-07 02:00:00        NaN        NaN       23.0
# 2019-05-07 03:00:00       50.5       25.0       19.0
# 2019-05-07 04:00:00       45.0       27.7       19.0
# 2019-05-07 05:00:00        NaN       50.4       16.0
# 2019-05-07 06:00:00        NaN       61.9        NaN

# %% [markdown]
# # **c. exploraando los datos**

# %%
# **c. exploraando los datos**
air_quality.describe()
# Out:
#        station_1    station_2   station_3
# count  95.000000  1004.000000  969.000000
# mean   25.778947    27.740538   24.777090
# std    12.682019    15.285746   11.214377
# min     7.500000     0.000000    0.000000
# 25%    16.750000    16.500000   19.000000
# 50%    23.000000    24.150000   25.000000
# 75%    34.500000    35.925000   31.000000
# max    74.500000    97.000000   97.000000

# %% [markdown]
# # **d. explorando los datos**

# %%
# **d. explorando los datos**
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1035 entries, 2019-05-07 02:00:00 to 2019-06-21 02:00:00
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   station_1  95 non-null     float64
#  1   station_2  1004 non-null   float64
#  2   station_3  969 non-null    float64
# dtypes: float64(3)
# memory usage: 32.3 KB

# %%
air_quality
# Out:
#                      station_1  station_2  station_3
# datetime
# 2019-05-07 02:00:00        NaN        NaN       23.0
# 2019-05-07 03:00:00       50.5       25.0       19.0
# 2019-05-07 04:00:00       45.0       27.7       19.0
# 2019-05-07 05:00:00        NaN       50.4       16.0
# 2019-05-07 06:00:00        NaN       61.9        NaN
# ...                        ...        ...        ...
# 2019-06-20 22:00:00        NaN       21.4        NaN
# 2019-06-20 23:00:00        NaN       24.9        NaN
# 2019-06-21 00:00:00        NaN       26.5        NaN
# 2019-06-21 01:00:00        NaN       21.8        NaN
# 2019-06-21 02:00:00        NaN       20.0        NaN
#
# [1035 rows x 3 columns]

# %% [markdown]
# # **2. Valores medios**

# %% [markdown]
# # **a. pasar de datos horarios a datos medios diarios**

# %%
# **a. pasar de datos horarios a datos medios diarios**
air_quality.resample('d').mean().head() # Promedia los datos de cada dia
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-05-07      47.75  33.900000  22.100000
# 2019-05-08      21.75  25.529167  26.478261
# 2019-05-09      20.25  27.837500  43.173913
# 2019-05-10      11.00  32.950000  34.625000
# 2019-05-11      23.75  26.804762  30.842105

# %% [markdown]
# # **b. Pasar de datos horarios a datos medios mensuales**

# %%
# **b. Pasar de datos horarios a datos medios mensuales**
air_quality.resample('m').mean()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-05-31  24.344156  27.749322  28.162116
# 2019-06-30  31.916667  27.728019  19.597911

# %% [markdown]
# # **c. Pasar de datos horarios a datos medios anuales**

# %%
# **c. Pasar de datos horarios a datos medios anuales**
air_quality.resample('y').mean()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-12-31  25.778947  27.740538   24.77709

# %% [markdown]
# # **3. Valores máximos**

# %% [markdown]
# # **a. Pasar de datos horarios a datos máximos diarios**

# %%
# **a. Pasar de datos horarios a datos máximos diarios**
air_quality.resample('d').max().head()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-05-07       50.5       77.7       32.0
# 2019-05-08       23.0       48.9       40.0
# 2019-05-09       20.5       50.7       97.0
# 2019-05-10       11.5       60.7       59.0
# 2019-05-11       26.5       36.8       37.0

# %% [markdown]
# # **b. Pasar de datos horarios a datos máximos mensuales**

# %%
# **b. Pasar de datos horarios a datos máximos mensuales**
air_quality.resample('m').max().head()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-05-31       74.5       97.0       97.0
# 2019-06-30       52.5       84.7       52.0

# %% [markdown]
# # **c. Pasar de datos horarios a datos máximos anuales**

# %%
# **c. Pasar de datos horarios a datos máximos anuales**
air_quality.resample('y').max().head()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-12-31       74.5       97.0       97.0

# %% [markdown]
# # **4. Valores mínimos**

# %% [markdown]
# # **a. Pasar de datos horarios a datos mínimos diarios**

# %%
# **a. Pasar de datos horarios a datos mínimos diarios**
air_quality.resample('d').min().head()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-05-07       45.0       10.6       16.0
# 2019-05-08       20.5       13.5       19.0
# 2019-05-09       20.0       10.0       25.0
# 2019-05-10       10.5       14.1       24.0
# 2019-05-11       21.0       14.9       26.0

# %% [markdown]
# # **b. Pasar de datos horarios a datos mínimos mensuales**

# %%
# **b. Pasar de datos horarios a datos mínimos mensuales**
air_quality.resample('m').min().head()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-05-31        7.5        0.0        0.0
# 2019-06-30        7.5        0.0        0.0

# %% [markdown]
# # **c. Pasar de datos horarios a datos mínimos anuales**

# %%
# **c. Pasar de datos horarios a datos mínimos anuales**

# %%
air_quality.resample('y').min().head()
# Out:
#             station_1  station_2  station_3
# datetime
# 2019-12-31        7.5        0.0        0.0

# %% [markdown]
# # **5. Visualización**

# %% [markdown]
# # **a. Función plot -  imprimir datos de estaciones**

# %%
# **a. Función plot -  imprimir datos de estaciones**
air_quality.plot()
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# # **b. plotear una sola estación**

# %%
# **b. plotear una sola estación**
air_quality['station_1'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
# plotear una sola estación
air_quality['station_2'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
# plotear una sola estación
air_quality['station_3'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# # **b. Cambiar el tamaño del gráfico**

# %%
# **b. Cambiar el tamaño del gráfico**
fix, ax = plt.subplots(figsize=(15,4))
air_quality.plot(ax=ax)
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# # **c. imprimer cada una de las columnas en graficos aparte**

# %%
# **c. imprimer cada una de las columnas en graficos aparte**
grafico = air_quality.plot(figsize=(15,4),subplots=True)

# %% [markdown]
# # **d. plotear un digrama de puntos**

# %%
# **d. plotear un digrama de puntos**
plt.scatter(air_quality['station_3'],air_quality['station_2'])

# %%
# plotear un digrama de puntos
plt.scatter(air_quality['station_3'],air_quality['station_2'], alpha = 0.5)

# %%
# plotear un digrama de puntos
plt.scatter(air_quality['station_3'],air_quality['station_2'], alpha = 0.5, color = 'red')

# %% [markdown]
# # **e. Cambiar el tamaño y tipo de gráfico**

# %%
# **e. Cambiar el tamaño y tipo de gráfico**
fix, ax = plt.subplots(figsize=(15,4))
air_quality.plot.area(ax=ax)
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# # **f. Construir un diagráma de cajas o boxplot**

# %%
# **f. Construir un diagráma de cajas o boxplot**
air_quality.plot.box()
# Out:
# <Axes: >
