# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/C_Datos/blob/main/11_C_Datos_Histogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso Introductorio a la Ciencia de Datos por Julio Hurtado Márquez**
# ## **Parte II**
# # **50. Importar y exportar dataframes limpios**

# %% [markdown]
# ## **a. Librerías básicas usadas hasta el momento**
# - Matplotlib es una biblioteca de trazado completa capaz de generar gráficos de alta calidad. Matplotlib contiene funciones de alto nivel que producen tipos específicos de figuras, por ejemplo, un gráfico de líneas simple o un gráfico de barras, así como una API de bajo nivel para crear gráficos altamente personalizados.

# %%
import pandas as pd
import numpy as np
## **a. Importando las librerias a necesitar**
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import scipy.stats as stats
from pandas.plotting import register_matplotlib_converters

# %% [markdown]
# ## **b. Exportamos nuestra última bbase de datos**

# %%
## **b. Exportamos nuestra última bbase de datos**
df_datos2 = pd.read_csv("/content/sample_data/df_datos_LIMPIOS2.csv", delimiter=',')
df_datos2
# Out:
#              CURSO  DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  \
# 0    ESTADISTICA I         4.3     COMS    18     SI    55       164
# 1    ESTADISTICA I         3.1     COMS    19     SI    65       165
# 2    ESTADISTICA I         4.2     DERH    25     NO    56       170
# 3    ESTADISTICA I         3.6     DERH    23     SI    65       170
# 4    ESTADISTICA I         3.9     PSIC    19     SI    50       169
# ..             ...         ...      ...   ...    ...   ...       ...
# 116  ESTADISTICA I         3.5     PSIC    18     SI    60       163
# 117  ESTADISTICA I         3.5     PSIC    18     SI    60       180
# 118  ESTADISTICA I         2.5     COMS    21     NO    45       172
# 119  ESTADISTICA I         3.0     COMS    20     NO    50       160
# 120  ESTADISTICA I         3.5     DERH    21     NO    57       160
#
#      SATISFACC  SABER 11  PROMEDIO SEXO ESTRATO Herramientas  Aris2  nota2
# ...

# %% [markdown]
# # **51. Gráficos Estadisticos: Líneas y Puntos**

# %% [markdown]
# ## **a. Gráficos de Lineas**

# %%
## **a. Gráficos de Lineas**
fig, ax = plt.subplots(1, 1, figsize=(8, 8)) #Tamaño del gráfico
ax.set_title('PROMEDIO') # Titulo principal
x = df_datos2['PROMEDIO'] # variable a graficar
plt.plot(x, 'r-') # r es para el color y '-' para la linea
# Show plot
plt.show()

# %% [markdown]
# ## **b. Gráficos de puntos**

# %%
## **b. Gráficos de puntos**
fig, ax = plt.subplots(1, 1, figsize=(8, 8)) #Tamaño del gráfico
ax.set_title('PROMEDIO') # Titulo principal
x = df_datos2['PROMEDIO'] # variable a graficar
plt.plot(x, 'r.') # r es para el color y '.' para los puntos
# Show plot
plt.show()

# %% [markdown]
# # **52. Gráficos Estadisticos: Histogramas**

# %% [markdown]
# ## **a. Histogramas para variable PROMEDIO**

# %%
## **a. Histogramas para variable PROMEDIO**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico
x = df_datos2['PROMEDIO'] # variable a graficar
plt.hist(x, bins=8, facecolor='red', label='PROMEDIO')
plt.title('Histograma PROMEDIO')
plt.xlabel('PROMEDIO')
plt.ylabel('número de Estudiantes')
plt.show()

# %% [markdown]
# ## **b. Agregando una estimación de la densidad del kernel**
# - Para suavizar el histograma y brindar información complementaria sobre la forma de la distribución:**

# %%
## **b. Agregando una estimación de la densidad del kernel**
sns.histplot(data=df_datos2, x="PROMEDIO", kde=True)
# Out:
# <Axes: xlabel='PROMEDIO', ylabel='Count'>

# %%
plt.figure(figsize=(8, 8)) #Tamaño del gráfico

sns.kdeplot(data=df_datos2, x="PROMEDIO", bw_adjust=5, cut=1)
# Out:
# <Axes: xlabel='PROMEDIO', ylabel='Density'>

# %% [markdown]
# ## **c. Histogramas para variable DEFINITIVA**

# %%
## **b. Histogramas para variable DEFINITIVA**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico
x = df_datos2['DEFINITIVA'] # variable a graficar
plt.hist(x, bins=8, facecolor='purple', label='DEFINITIVA')
plt.title('Histograma DEFINITIVA')
plt.xlabel('DEFINITIVA')
plt.ylabel('número de Estudiantes')
plt.show()

# %% [markdown]
# ## **d. Agregando una estimación de la densidad del kernel**

# %%
## **d. Agregando una estimación de la densidad del kernel**
sns.histplot(data=df_datos2, x="DEFINITIVA", kde=True)
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **Colores**
#
# COLORS = ['snow', 'ghost white', 'white smoke', 'gainsboro', 'floral white', 'old lace',
#           'linen', 'antique white', 'papaya whip', 'blanched almond', 'bisque', 'peach puff',
#           'navajo white', 'lemon chiffon', 'mint cream', 'azure', 'alice blue', 'lavender',
#           'lavender blush', 'misty rose', 'dark slate gray', 'dim gray', 'slate gray',
#           'light slate gray', 'gray', 'light gray', 'midnight blue', 'navy', 'cornflower blue', 'dark slate blue',
#           'slate blue', 'medium slate blue', 'light slate blue', 'medium blue', 'royal blue',  'blue',
#           'dodger blue', 'deep sky blue', 'sky blue', 'light sky blue', 'steel blue', 'light steel blue',
#           'light blue', 'powder blue', 'pale turquoise', 'dark turquoise', 'medium turquoise', 'turquoise',
#           'cyan', 'light cyan', 'cadet blue', 'medium aquamarine', 'aquamarine', 'dark green', 'dark olive green',
#           'dark sea green', 'sea green', 'medium sea green', 'light sea green', 'pale green', 'spring green',
#           'lawn green', 'medium spring green', 'green yellow', 'lime green', 'yellow green',
#           'forest green', 'olive drab', 'dark khaki', 'khaki', 'pale goldenrod', 'light goldenrod yellow',
#           'light yellow', 'yellow', 'gold', 'light goldenrod', 'goldenrod', 'dark goldenrod', 'rosy brown',
#           'indian red', 'saddle brown', 'sandy brown',
#           'dark salmon', 'salmon', 'light salmon', 'orange', 'dark orange',
#           'coral', 'light coral', 'tomato', 'orange red', 'red', 'hot pink', 'deep pink', 'pink', 'light pink',
#           'pale violet red', 'maroon', 'medium violet red', 'violet red',
#           'medium orchid', 'dark orchid', 'dark violet', 'blue violet', 'purple', 'medium purple',
#           'thistle', 'snow2', 'snow3',
#           'snow4', 'seashell2', 'seashell3', 'seashell4', 'AntiqueWhite1', 'AntiqueWhite2',
#           'AntiqueWhite3', 'AntiqueWhite4', 'bisque2', 'bisque3', 'bisque4', 'PeachPuff2',
#           'PeachPuff3', 'PeachPuff4', 'NavajoWhite2', 'NavajoWhite3', 'NavajoWhite4',
#           'LemonChiffon2', 'LemonChiffon3', 'LemonChiffon4', 'cornsilk2', 'cornsilk3',
#           'cornsilk4', 'ivory2', 'ivory3', 'ivory4', 'honeydew2', 'honeydew3', 'honeydew4',
#           'LavenderBlush2', 'LavenderBlush3', 'LavenderBlush4', 'MistyRose2', 'MistyRose3',
#           'MistyRose4', 'azure2', 'azure3', 'azure4', 'SlateBlue1', 'SlateBlue2', 'SlateBlue3',
#           'SlateBlue4', 'RoyalBlue1', 'RoyalBlue2', 'RoyalBlue3', 'RoyalBlue4', 'blue2', 'blue4',
#           'DodgerBlue2', 'DodgerBlue3', 'DodgerBlue4', 'SteelBlue1', 'SteelBlue2',
#           'SteelBlue3', 'SteelBlue4', 'DeepSkyBlue2', 'DeepSkyBlue3', 'DeepSkyBlue4',
#           'SkyBlue1', 'SkyBlue2', 'SkyBlue3', 'SkyBlue4', 'LightSkyBlue1', 'LightSkyBlue2',
#           'LightSkyBlue3', 'LightSkyBlue4', 'Slategray1', 'Slategray2', 'Slategray3',
#           'Slategray4', 'LightSteelBlue1', 'LightSteelBlue2', 'LightSteelBlue3',
#           'LightSteelBlue4', 'LightBlue1', 'LightBlue2', 'LightBlue3', 'LightBlue4',
#           'LightCyan2', 'LightCyan3', 'LightCyan4', 'PaleTurquoise1', 'PaleTurquoise2',
#           'PaleTurquoise3', 'PaleTurquoise4', 'CadetBlue1', 'CadetBlue2', 'CadetBlue3',
#           'CadetBlue4', 'turquoise1', 'turquoise2', 'turquoise3', 'turquoise4', 'cyan2', 'cyan3',
#           'cyan4', 'DarkSlategray1', 'DarkSlategray2', 'DarkSlategray3', 'DarkSlategray4',
#           'aquamarine2', 'aquamarine4', 'DarkSeaGreen1', 'DarkSeaGreen2', 'DarkSeaGreen3',
#           'DarkSeaGreen4', 'SeaGreen1', 'SeaGreen2', 'SeaGreen3', 'PaleGreen1', 'PaleGreen2',
#           'PaleGreen3', 'PaleGreen4', 'SpringGreen2', 'SpringGreen3', 'SpringGreen4',
#           'green2', 'green3', 'green4', 'chartreuse2', 'chartreuse3', 'chartreuse4',
#           'OliveDrab1', 'OliveDrab2', 'OliveDrab4', 'DarkOliveGreen1', 'DarkOliveGreen2',
#           'DarkOliveGreen3', 'DarkOliveGreen4', 'khaki1', 'khaki2', 'khaki3', 'khaki4',
#           'LightGoldenrod1', 'LightGoldenrod2', 'LightGoldenrod3', 'LightGoldenrod4',
#           'LightYellow2', 'LightYellow3', 'LightYellow4', 'yellow2', 'yellow3', 'yellow4',
#           'gold2', 'gold3', 'gold4', 'goldenrod1', 'goldenrod2', 'goldenrod3', 'goldenrod4',
#           'DarkGoldenrod1', 'DarkGoldenrod2', 'DarkGoldenrod3', 'DarkGoldenrod4',
#           'RosyBrown1', 'RosyBrown2', 'RosyBrown3', 'RosyBrown4', 'IndianRed1', 'IndianRed2',
#           'IndianRed3', 'IndianRed4', 'sienna1', 'sienna2', 'sienna3', 'sienna4', 'burlywood1',
#           'burlywood2', 'burlywood3', 'burlywood4', 'wheat1', 'wheat2', 'wheat3', 'wheat4', 'tan1',
#           'tan2', 'tan4', 'chocolate1', 'chocolate2', 'chocolate3', 'firebrick1', 'firebrick2',
#           'firebrick3', 'firebrick4', 'brown1', 'brown2', 'brown3', 'brown4', 'salmon1', 'salmon2',
#           'salmon3', 'salmon4', 'LightSalmon2', 'LightSalmon3', 'LightSalmon4', 'orange2',
#           'orange3', 'orange4', 'DarkOrange1', 'DarkOrange2', 'DarkOrange3', 'DarkOrange4',
#           'coral1', 'coral2', 'coral3', 'coral4', 'tomato2', 'tomato3', 'tomato4', 'OrangeRed2',
#           'OrangeRed3', 'OrangeRed4', 'red2', 'red3', 'red4', 'DeepPink2', 'DeepPink3', 'DeepPink4',
#           'HotPink1', 'HotPink2', 'HotPink3', 'HotPink4', 'pink1', 'pink2', 'pink3', 'pink4',
#           'LightPink1', 'LightPink2', 'LightPink3', 'LightPink4', 'PaleVioletRed1',
#           'PaleVioletRed2', 'PaleVioletRed3', 'PaleVioletRed4', 'maroon1', 'maroon2',
#           'maroon3', 'maroon4', 'VioletRed1', 'VioletRed2', 'VioletRed3', 'VioletRed4',
#           'magenta2', 'magenta3', 'magenta4', 'orchid1', 'orchid2', 'orchid3', 'orchid4', 'plum1',
#           'plum2', 'plum3', 'plum4', 'MediumOrchid1', 'MediumOrchid2', 'MediumOrchid3',
#           'MediumOrchid4', 'DarkOrchid1', 'DarkOrchid2', 'DarkOrchid3', 'DarkOrchid4',
#           'purple1', 'purple2', 'purple3', 'purple4', 'MediumPurple1', 'MediumPurple2',
#           'MediumPurple3', 'MediumPurple4', 'thistle1', 'thistle2', 'thistle3', 'thistle4',
#           'grey1', 'grey2', 'grey3', 'grey4', 'grey5', 'grey6', 'grey7', 'grey8', 'grey9', 'grey10',
#           'grey11', 'grey12', 'grey13', 'grey14', 'grey15', 'grey16', 'grey17', 'grey18', 'grey19',
#           'grey20', 'grey21', 'grey22', 'grey23', 'grey24', 'grey25', 'grey26', 'grey27', 'grey28',
#           'grey29', 'grey30', 'grey31', 'grey32', 'grey33', 'grey34', 'grey35', 'grey36', 'grey37',
#           'grey38', 'grey39', 'grey40', 'grey42', 'grey43', 'grey44', 'grey45', 'grey46', 'grey47',
#           'grey48', 'grey49', 'grey50', 'grey51', 'grey52', 'grey53', 'grey54', 'grey55', 'grey56',
#           'grey57', 'grey58', 'grey59', 'grey60', 'grey61', 'grey62', 'grey63', 'grey64', 'grey65',
#           'grey66', 'grey67', 'grey68', 'grey69', 'grey70', 'grey71', 'grey72', 'grey73', 'grey74',
#           'grey75', 'grey76', 'grey77', 'grey78', 'grey79', 'grey80', 'grey81', 'grey82', 'grey83',
#           'grey84', 'grey85', 'grey86', 'grey87', 'grey88', 'grey89', 'grey90', 'grey91', 'grey92',
#           'grey93', 'grey94', 'grey95', 'grey97', 'grey98', 'grey99']

# %% [markdown]
# ## **e. Histogramas para variable PESO**

# %%
## **c. Histogramas para variable PESO**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico
x = df_datos2['PESO'] # variable a graficar
plt.hist(x, bins=8, facecolor='Violet', label='PESO')
plt.title('Histograma PESO')
plt.xlabel('PESO')
plt.ylabel('número de Estudiantes')
plt.show()

# %% [markdown]
# ## **e. Agregando una estimación de la densidad del kernel**

# %%
## **e. Agregando una estimación de la densidad del kernel**
sns.histplot(data=df_datos2, x="PESO", kde=True)
# Out:
# <Axes: xlabel='PESO', ylabel='Count'>

# %% [markdown]
# ## **f. Histogramas para variable ESTATURA**

# %%
## **f. Histogramas para variable ESTATURA**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico
x = df_datos2['ESTATURA'] # variable a graficar
plt.hist(x, bins=8, facecolor='salmon', label='ESTATURA')
plt.title('Histograma ESTATURA')
plt.xlabel('ESTATURA')
plt.ylabel('número de Estudiantes')
plt.show()

# %% [markdown]
# ## **g. Agregando una estimación de la densidad del kernel**

# %%
## **g. Agregando una estimación de la densidad del kernel**
sns.histplot(data=df_datos2, x="ESTATURA", kde=True)
# Out:
# <Axes: xlabel='ESTATURA', ylabel='Count'>

# %% [markdown]
# # **53. Gráficos Estadisticos: Histogramas Múltiples**

# %% [markdown]
# ## **a. Histograma multiple con todas las variables cuantitativas de la base de datos**

# %%
## **a. Histograma multiple con todas las variables cuantitativas de la base de datos**
sns.histplot(data=df_datos2)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## **b. crear histograma para EDAD, PESO, ESTATURA**

# %%
## **a. crear histograma para EDAD, PESO, ESTATURA, SABER 11**
plt.figure(figsize=(10, 8))
n, bins, patches = plt.hist(df_datos2['EDAD'], 8, 
                            facecolor='red', label='EDAD')
n, bins, patches = plt.hist(df_datos2['PESO'], 8, 
                            facecolor='green', label='PESO')
n, bins, patches = plt.hist(df_datos2['ESTATURA'], 8, 
                            facecolor='blue', label='ESTATURA')
n, bins, patches = plt.hist(df_datos2['SABER 11'], 8, 
                            facecolor='salmon', label='SABER 11')

plt.title('Histograma Múltiple')
plt.xlabel('valores de x')
plt.ylabel('número de Estudiantes')
plt.show()

# %% [markdown]
# ## **c. crear histograma para DEFINITIVA, PROMEDIO**

# %%
## **b. crear histograma para DEFINITIVA, PROMEDIO**
plt.figure(figsize=(10, 8))
n, bins, patches = plt.hist(df_datos2['DEFINITIVA'], 8, 
                            facecolor='red')
n, bins, patches = plt.hist(df_datos2['PROMEDIO'], 8, 
                            facecolor='green')


plt.title('Histograma Múltiple')
plt.xlabel('valores de x')
plt.ylabel('número de Estudiantes')
plt.show()

# %% [markdown]
# # **54. El turno para crear Histogramas bivariados con Python: Cuantitativa vs Cualitativa**

# %% [markdown]
# ## **a. Un histograma con las variables DEFINITIVA vs SEXO**

# %%
## **a. Un histograma con las variables DEFINITIVA vs SEXO**
sns.histplot(df_datos2, x="DEFINITIVA", hue="SEXO")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **b. Un histograma con las variables DEFINITIVA vs SEXO con element="step"**

# %%
## **b. Un histograma con las variables DEFINITIVA vs SEXO con element="step"**
sns.histplot(df_datos2, x="DEFINITIVA", hue="SEXO", element="step")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **c. Un histograma de densidad para las variables DEFINITIVA vs SEXO - stat="density"**

# %%
## **c. Un histograma de densidad para las variables DEFINITIVA vs SEXO - stat="density"**
sns.histplot(
    df_datos2, x="DEFINITIVA", hue="SEXO", element="step",
    stat="density", common_norm=False,
)
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Density'>

# %% [markdown]
# ## **d. Un histograma con las variables DEFINITIVA vs SEXO - multiple="stack"**

# %%
## **d. Un histograma con las variables DEFINITIVA vs SEXO - multiple="stack"**
sns.histplot(df_datos2, x="DEFINITIVA", hue="SEXO", multiple="stack")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **e. Un histograma con las variables DEFINITIVA vs SEXO - element="poly"**

# %%
## **e. Un histograma con las variables DEFINITIVA vs SEXO - element="poly"**
sns.histplot(df_datos2, x="DEFINITIVA", hue="SEXO", element="poly")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **f. Estimación de densidad kernel (KDE) - PROMEDIO vs SEXO**
# - Es un método para visualizar la distribución de observaciones en un conjunto de datos, de forma análoga a un histograma. **

# %%
## **f. Estimación de densidad kernel (KDE) - PROMEDIO vs SEXO**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico

sns.kdeplot(data=df_datos2, x="PROMEDIO", hue="SEXO", bw_adjust=5, cut=1)
# Out:
# <Axes: xlabel='PROMEDIO', ylabel='Density'>

# %% [markdown]
# ## **g. Un histograma con las variables DEFINITIVA vs ESTRATO**

# %%
## **g. Un histograma con las variables DEFINITIVA vs ESTRATO**
sns.histplot(df_datos2, x="DEFINITIVA", hue="ESTRATO", element="poly")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **h. Estimación de densidad kernel (KDE) - DEFINITIVA vs ESTRATO**

# %%
## **h. Estimación de densidad kernel (KDE) - DEFINITIVA vs ESTRATO**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico

sns.kdeplot(data=df_datos2, x="DEFINITIVA", hue="ESTRATO", bw_adjust=5, cut=1)
# Out:
# <ipython-input-24-c0d568f1697d>:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df_datos2, x="DEFINITIVA", hue="ESTRATO", bw_adjust=5, cut=1)
# <Axes: xlabel='DEFINITIVA', ylabel='Density'>

# %% [markdown]
# ## **i. Un histograma con las variables DEFINITIVA vs URBANO**

# %%
## **i. Un histograma con las variables DEFINITIVA vs URBANO**
sns.histplot(df_datos2, x="DEFINITIVA", hue="URBANO", element="poly")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **j. Estimación de densidad kernel (KDE) - DEFINITIVA vs URBANO**

# %%
## **j. Estimación de densidad kernel (KDE) - DEFINITIVA vs URBANO**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico

sns.kdeplot(data=df_datos2, x="DEFINITIVA", hue="URBANO", bw_adjust=3, cut=1)
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Density'>

# %% [markdown]
# ## **k. Un histograma con las variables DEFINITIVA vs CURSO**

# %%
## **k. Un histograma con las variables DEFINITIVA vs CURSO**
sns.histplot(df_datos2, x="DEFINITIVA", hue="CURSO", element="poly")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Count'>

# %% [markdown]
# ## **l. Estimación de densidad kernel (KDE) - DEFINITIVA vs CURSO**

# %%
## **l. Estimación de densidad kernel (KDE) - DEFINITIVA vs CURSO**
plt.figure(figsize=(8, 8)) #Tamaño del gráfico

sns.kdeplot(data=df_datos2, x="DEFINITIVA", hue="CURSO", bw_adjust=3, cut=1)
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='Density'>

# %% [markdown]
# # **55. El turno para crear Diagrama de barras con Python y seaborn**

# %% [markdown]
# ## **a. Grafíco de Barras CURSO Vs DEFNITIVA**

# %%
## **a. Grafíco de Barras CURSO Vs DEFNITIVA**
sns.barplot(data=df_datos2, x="CURSO", y="DEFINITIVA")
# Out:
# <Axes: xlabel='CURSO', ylabel='DEFINITIVA'>

# %% [markdown]
# ## **b. Grafíco de Barras CURSO Vs DEFNITIVA Vs SEXO**

# %%
## **b. Grafíco de Barras CURSO Vs DEFNITIVA Vs SEXO**
sns.barplot(data=df_datos2, x="CURSO", y="DEFINITIVA", hue="SEXO")
# Out:
# <Axes: xlabel='CURSO', ylabel='DEFINITIVA'>

# %% [markdown]
# ## **c. Grafíco de Barras URBANO Vs DEFNITIVA Vs SEXO**

# %%
## **c. Grafíco de Barras URBANO Vs DEFNITIVA Vs SEXO**
sns.barplot(data=df_datos2, x="URBANO", y="DEFINITIVA", hue="SEXO")
# Out:
# <Axes: xlabel='URBANO', ylabel='DEFINITIVA'>

# %% [markdown]
# ## **d. Grafíco de Barras ESTRATO Vs DEFNITIVA Vs SEXO**
#  - _Utilice las barras de error para mostrar la desviación estándar en lugar de un intervalo de confianza_

# %%
## **d. Grafíco de Barras ESTRATO Vs DEFNITIVA Vs SEXO**
sns.barplot(data=df_datos2, x="ESTRATO", y="DEFINITIVA", hue="SEXO", errorbar="sd")
# Out:
# <Axes: xlabel='ESTRATO', ylabel='DEFINITIVA'>

# %% [markdown]
# ## **e. Grafíco de Barras ESTRATO Vs DEFNITIVA Vs SEXO**
# - Personaliza la apariencia de la trama:

# %%
## **e. Grafíco de Barras ESTRATO Vs DEFNITIVA Vs SEXO**
sns.barplot(
    data=df_datos2, x="ESTRATO", y="DEFINITIVA",
    errorbar=("pi", 50), capsize=.4, errcolor=".1",
    linewidth=3, edgecolor=".5",hue="SEXO",
)
# Out:
# <Axes: xlabel='ESTRATO', ylabel='DEFINITIVA'>

# %% [markdown]
# # **56. Box_plot con seaborn**

# %% [markdown]
# ## **a. Boxplot para EDAD**

# %%
## **a. Boxplot para EDAD**
sns.boxplot(x=df_datos2["EDAD"])
# Out:
# <Axes: xlabel='EDAD'>

# %% [markdown]
# ## **b. Boxplot EDAD vs SEXO**

# %%
## **b. Boxplot EDAD vs SEXO**
sns.boxplot(data=df_datos2, x="EDAD", y="SEXO")
# Out:
# <Axes: xlabel='EDAD', ylabel='SEXO'>

# %% [markdown]
# ## **c. Boxplot EDAD vs SEXO vs CURSO**

# %%
## **c. Boxplot EDAD vs SEXO vs CURSO**
sns.boxplot(data=df_datos2, x="EDAD", y="SEXO", hue="CURSO")
# Out:
# <Axes: xlabel='EDAD', ylabel='SEXO'>

# %% [markdown]
# ## **d. Boxplot DEFINITIVA vs SEXO vs CURSO**

# %%
## **d. Boxplot DEFINITIVA vs SEXO vs CURSO**
sns.boxplot(data=df_datos2, x="DEFINITIVA", y="SEXO", hue="CURSO")
# Out:
# <Axes: xlabel='DEFINITIVA', ylabel='SEXO'>

# %% [markdown]
# ## **e. Dos variables cuantitativas - Boxplot ESTATURA vs PESO**

# %%
## **e. Dos variables cuantitativas - Boxplot ESTATURA vs PESO**
sns.boxplot(data=df_datos2[["ESTATURA", "PESO"]], orient="h")
# Out:
# <Axes: >

# %%
df_datos2.columns
# Out:
# Index(['CURSO', 'DEFINITIVA', 'PROGRAMA', 'EDAD', 'URBANO', 'PESO', 'ESTATURA',
#        'SATISFACC', 'SABER 11', 'PROMEDIO', 'SEXO', 'ESTRATO', 'Herramientas',
#        'Aris2', 'nota2'],
#       dtype='object')

# %% [markdown]
# ## **f. Tres variables Una cuantitativas y dos cualitativas - Boxplot DEFINITIVA vs SEXO vs CURSO**

# %%
## **f. Tres variables Una cuantitativas y dos cualitativas - Boxplot DEFINITIVA vs SEXO vs CURSO **
sns.boxplot(data=df_datos2, x ="DEFINITIVA", y = "SEXO", orient="h", hue="CURSO" )
# Out:
# <Axes: xlabel='PROMEDIO', ylabel='SEXO'>
