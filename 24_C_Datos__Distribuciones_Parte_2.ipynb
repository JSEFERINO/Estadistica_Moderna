# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/C_Datos/blob/main/24_C_Datos__Distribuciones_Parte_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso Introductorio a la Ciencia de Datos por Julio Hurtado Márquez**
# ## **Parte IX- Encontrar la mejor distribución que se ajuste a sus datos usando la biblioteca Fitter de Python-**
# # **137. Distribuciones - KEGG Metabolic Reaction Network (Undirected) Donated on 11/27/2011**
# - Base de datos: https://archive-beta.ics.uci.edu/dataset/221/kegg+metabolic+reaction+network+undirected
# - KEGG Vías metabólicas modeladas como red de reacción no dirigida. Variedad de características gráficas presentadas.
#
# - Características del conjunto de datos: Multivariante, Univariante, Texto
# - Área temática: Vida
# - Tareas asociadas: Clasificación, regresión, agrupamiento
# - Tipo de atributo: entero, real
# - Instancias: 65554
# - Atributos: 29
#
# - **información adicional**.
# - - Las vías metabólicas de KEGG se pueden realizar en red.
# - - Se pueden formar dos tipos de red/grafo. Estos incluyen Red de reacción y Red de relación.
# - - En la red de reacción, el compuesto de sustrato o producto se considera como nodo y los genes se tratan como borde.
# - - Mientras que en la red de relaciones, los componentes Sustrato y Producto se consideran Bordes, mientras que la enzima y los genes se colocan como nodos. - - Utilizamos una gran cantidad de rutas metabólicas de KEGG XML.
# - - Se modelaron en el gráfico como se describe anteriormente. Con la ayuda de la herramienta Cytoscape, se calcularon una variedad de características de la red.
#
# - **Attribute Information**
#
# - - a)	Pathway	text
# - - b)	Connected Components	Integer (min:1, max:39 )
# - - c)	Diameter	Integer (min:1, max:46 )
# - - d)	Radius	Integer (min:1, max:13 )
# - - e)	Centralization	Integer (min:0, max:1 )
# - - f)	Shortest Path	Integer (min:2, max:23420 )
# - - g)	Characteristic Path Length	Integer (min:1, max:15.9729 )
# - - h)	Avg.num.Neighbours	real (min:0.67, max:3.44)
# - - i)	Density	real (min:0.0082, max:1)
# - - j)	Heterogeneity	real (min:0, max:1.796)
# - - k)	Isolated Nodes	Integer (min:0, max:3)
# - - l)	Number of Self Loops	Integer (min:0, max:4)
# - - m)	Multi-edge Node Pair	Integer (min:0, max:220)
# - - n)	NeighborhoodConnectivity	real (min:0.67, max:15.604)
# - - o)	NumberOfDirectedEdges		real (min:0.67, max:10.22)
# - - p)	Stress		real (min:0, max:2112.05)
# - - q)	SelfLoops		real (min:0, max:0.67)
# - - r)	Partner Of MultiEdged NodePairs		Integer (min:0, max:3)
# - - s)	Degree		real (min:1, max:10.22)
# - - t)	TopologicalCoefficient	real (min:0, max:1)
# - - u)	BetweennessCentrality		real (min:0, max:0.333)
# - - v)	Radiality		real (min:0.5437, max:30744573457 )
# - - w)	Eccentricity	real (min:0.67, max:25.034)
# - - x)	NumberOfUndirectedEdges	real (min:0, max:0.67)
# - - y)	ClosenessCentrality	real (min:0.1022, max:1)
# - - z)	AverageShortestPathLength	real (min:0.67, max:12.67 )
# - - aa)	ClusteringCoefficient		real (min:0, max:1)
# - - bb)	nodeCount		Integer (min:2, max:232)
# - - cc)	edgeCount	Integer (min:1, max:444)
#
# - **Español: Información de atributo**
#
# - - a) Texto de ruta b) Entero de componentes conectados (min:1, max:39 ) c) Entero de diámetro (min:1, max:46 ) d) Entero de radio (min:1, max:13 ) e) Entero de centralización (min :0, max:1 ) f) Entero de ruta más corta (min:2, max:23420 ) g) Entero de longitud de ruta característica (min:1, max:15.9729 ) h) Núm. promedio de vecinos reales (min:0.67, max :3.44) i) Densidad real (min:0.0082, max:1) j) Heterogeneidad real (min:0, max:1.796) k) Nodos aislados Entero (min:0, max:3) l) Número de Self Loops Entero (min:0, max:4) m) Entero de par de nodos de múltiples ejes (min:0, max:220) n) NeighborhoodConnectivity real (min:0.67, max:15.604) o) NumberOfDirectedEdges real (min:0.67, max: 10.22) p) Estrés real (min:0, max:2112.05) q) SelfLoops real (min:0, max:0.67) r) Compañero de pares de nodos de múltiples bordes Entero (min:0, max:3) s) Grado real (min :1, máx.:10.22) t) Coeficiente Topológico real (min:0, max:1) u) Intermediación Centralidad real (min:0, max:0.333) v) Radialidad real (min:0.5437, max:30744573457 ) w) Excentricidad real (min:0.67, max:25.034) x) NumberOfUndirectedEdges real (min:0, max:0.67) y) ClosenessCentrality real (min:0.1022, max:1) z) AverageShortestPathLength real (min:0.67, max:12.67 ) aa) ClusteringCoficient real (min: 0, max:1) bb) nodeCount Entero (min:2, max:232) cc) edgeCount Entero (min:1, max:444)0, max:1) bb) nodeCount Entero (min:2, max:232) cc) edgeCount Entero (min:1, max:444)0, max:1) bb) nodeCount Entero (min:2, max:232) cc) edgeCount Entero (min:1, max:444)

# %% [markdown]
# # **a. Nuestras librerias a usar**

# %%
# **a. Nuestras librerias a usar**
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # **b. Importamos el archivo que será como ejemplo para nuestro trabajo**

# %%
# **b. Nuestro archivo como ejemplo de trabajo**
import cv2 as cv
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-fa6fd72c-b6ec-4cff-8f71-0aa5aa0efa9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa6fd72c-b6ec-4cff-8f71-0aa5aa0efa9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **c. Tenemos nuestro DataFrame**
# + **Seleccione un conjunto de datos**.
# + + Trabajaremos con un conjunto de datos de 150 flores diferentes, o 50 de cada una de tres especies diferentes de iris (Iris setosa, Iris versicolor e Iris virginica).

# %%
# **c. Tenemos nuestro DataFrame**
data=pd.read_csv("Reaction_Network_mejorada (2).csv",delimiter=',')
data
# Out:
#           Texto  C_conectados  diámetro  radio centralización  Ruta_más_corta  \
# 0      aac00010             1        15      8    0.086580087             506
# 1      aac00020             1         7      5    0.091503268             342
# 2      aac00030             2         8      1    0.177489177             386
# 3      aac00040             5         5      1    0.087719298              92
# 4      aac00051             2         5      1    0.196969697             112
# ...         ...           ...       ...    ...            ...             ...
# 65549  zmo00950             1         1      1              ?               2
# 65550  zmo00960             3         1      1              0               6
# 65551  zmo00970            18         3      1    0.048051948             132
# 65552  zmo00980            15         2      1    0.028409091              46
# 65553  zmo01040             1         3      2    0.266666667              42
#
# ...

# %%
data.columns
# Out:
# Index(['Texto', 'C_conectados', 'diámetro', 'radio', 'centralización',
#        'Ruta_más_corta', 'Longitud_ruta', 'Prom.num.Neighbours', 'Densidad',
#        'Heterogeneidad', 'Nodos_aislados', 'Self_Loops',
#        'Nodos_de_varios ejes', 'Conectividad_vecindario', 'NumberOfDirected',
#        'Estrés_real', 'SelfLoops', 'Partner', 'Grado real', 'EdgeCount',
#        'C_Topológico', 'BetweennessCentrality', 'Ingrado_real',
#        'Excentricidad_real', 'NumberOfUndirectedEdges', 'CercaníaCentralidad',
#        'Average', 'Coeficienteagrupamiento', 'nodeCount'],
#       dtype='object')

# %% [markdown]
# #**d. Seleccionemos las columnas numéricas de _data_**

# %%
#**d. Seleccionemos las columnas numéricas de _data_**
data2 = data.select_dtypes(include = ["int64", "float64"]) # Seleccionamos las columnas discretas y las continuas
data2.head(10) # renombramos la data y visualizamos los 10 primeros datos
# Out:
#    C_conectados  diámetro  radio  Ruta_más_corta  Longitud_ruta  \
# 0             1        15      8             506       5.905138
# 1             1         7      5             342       3.309942
# 2             2         8      1             386       3.191710
# 3             5         5      1              92       2.304348
# 4             2         5      1             112       2.446429
# 5             3         7      1             424       3.009434
# 6             1         7      4            1482       3.700405
# 7             3         8      1             942       3.397028
# 8             1         3      2              20       1.600000
# 9             2         6      2              84       2.476190
#
#    Prom.num.Neighbours  Densidad  Heterogeneidad  Nodos_aislados  Self_Loops  \
# 0             2.260870  0.102767        0.350401               0           0
# 1             2.526316  0.140351        0.324091               0           0
# ...

# %% [markdown]
# # **e. Construyamos los Histogramas  para las Variables correlacionadas en la data**
#
# - - diámetro vs Longitud_ruta,  r = 0.98
# - - diámetro vs Estrés_real, r = 0.75
# - - diámetro vs Ingrado_real, r = 0.97
# - - diámetro vs NumberOfUndirectedEdges, r = -0.86
# - - diámetro vs CercaníaCentralidad, r = 0.96
# - - diámetro vs nodeCount, r = 0.73
# - - Ruta_más_corta vs Nodos_de_varios ejes
# - - Ruta_más_corta vs Estrés_real, r = 0.92
# - - Ruta_más_corta vs nodeCount, r = 0.84
# - - Longitud_ruta vs Estrés_real, r = 0.76
# - - Longitud_ruta vs Ingrado_real, r = 0.98
# - - Longitud_ruta vs NumberOfUndirectedEdges, r = -0.88
# - - Longitud_ruta vs CercaníaCentralidad, r = 0.99
# - - Longitud_ruta vs nodeCount, r = 0.72
# - - Prom.num.Neighbours vs Conectividad_vecindario, r = 0.85
# - - Prom.num.Neighbours vs NumberOfDirected, r = 0.82
# - - Prom.num.Neighbours vs Grado real, r = 0.82
# - - Prom.num.Neighbours vs EdgeCount, r = 0.83
# - - Prom.num.Neighbours vs NumberOfUndirectedEdges, r = -0.84
# - - Heterogeneidad vs Conectividad_vecindario,  r = 0.81
# - - Nodos_aislados vs SelfLoops, r = 0.81
# - - Nodos_aislados vs BetweennessCentrality, r = 0.87
# - - Nodos_aislados vs Excentricidad_real, r = 0.81
# - - Self_Loops vs SelfLoops, r = 0.86
# - - Self_Loops vs Excentricidad_real, r = 0.86
# - - Nodos_de_varios ejes vs NumberOfDirected, r = 0.75
# - - Nodos_de_varios ejes vs Estrés_real, r = 0.72
# - - Nodos_de_varios ejes vs Partner, r = 0.74
# - - Nodos_de_varios ejes vs Grado real, r = 0.75
# - - Nodos_de_varios ejes vs nodeCount, r = 0.72
# - - Conectividad_vecindario vs NumberOfDirected, r = 0.73
# - - Conectividad_vecindario vs Grado real, r = 0.73
# - - Conectividad_vecindario vs NumberOfUndirectedEdges, r = -0.75
# - - NumberOfDirected vs Partner, r = 0.88
# - - Estrés_real vs Ingrado_real, r = 0.78
# - - Estrés_real vs CercaníaCentralidad, r = 0.77
# - - Estrés_real vs nodeCount, r = 0.8
# - - Partner vs EdgeCount, r =0.88
# - - BetweennessCentrality vs Excentricidad_real, r = 0.89
# - - Ingrado_real vs NumberOfUndirectedEdges, r = -0.89
# - - Ingrado_real vs CercaníaCentralidad, r = 0.99
# - - Ingrado_real vs nodeCount, r = 0.70
# - - NumberOfUndirectedEdges vs CercaníaCentralidad, r = -0.9
# - - CercaníaCentralidad vs nodeCount, r = 0.70
# - - Coeficienteagrupamiento vs nodeCount, r = 0.85

# %%
# **e. Construyamos los Histogramas para cada Especie de Flor**
cols=data.columns[1:-1]
N=len(cols)
plt.figure(figsize=(10,5))
plt.subplot(141)
sns.histplot(data2['diámetro'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(142)
sns.histplot(data2['Longitud_ruta'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(143)
sns.histplot(data2['Estrés_real'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(144)
sns.histplot(data2['Ingrado_real'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.show()

# %% [markdown]
# # **138. Vamos a escalar la data data2 para hacerla comparable y mejorar a visibilidad**

# %% [markdown]
# # **a. Escalando la data2 para hacerla comparable**

# %%
# **a. Escalando la data2 para hacerla comparable**
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
data_scale = scale.fit_transform(data2)
data_scale
# Out:
# array([[-0.78443935,  3.28004169,  5.99777627, ...,  1.72300666,
#          0.83997414,  1.45689127],
#        [-0.78443935,  0.82932389,  3.2564383 , ...,  0.45282081,
#          0.47884291,  1.45689127],
#        [-0.40684723,  1.13566362, -0.39867899, ...,  1.0761285 ,
#          0.83997414,  2.10491071],
#        ...,
#        [ 5.63462655, -0.39603501, -0.39867899, ..., -0.35032076,
#          3.90958958,  1.24088479],
#        [ 4.50185022, -0.70237474, -0.39867899, ..., -0.35032076,
#          1.83308502,  0.10685078],
#        [-0.78443935, -0.39603501,  0.51510033, ..., -0.35032076,
#         -0.60455078, -0.27116056]])

# %% [markdown]
# # **b. Ahora veamos nuestro DataFrame imputado como la matriz de transformación**

# %%
# **b. Ahora veamos nuestro DataFrame imputado como la matriz de transformación**
data1=pd.DataFrame(data_scale,columns=data2.columns)
data1
# Out:
#        C_conectados  diámetro     radio  Ruta_más_corta  Longitud_ruta  \
# 0         -0.784439  3.280042  5.997776        1.207482       3.320007
# 1         -0.784439  0.829324  3.256438        0.674720       1.058305
# 2         -0.406847  1.135664 -0.398679        0.817656       0.955267
# 3          0.725929  0.216644 -0.398679       -0.137416       0.181935
# 4         -0.406847  0.216644 -0.398679       -0.072445       0.305758
# ...             ...       ...       ...             ...            ...
# 65549     -0.784439 -1.008714 -0.398679       -0.429786      -0.954798
# 65550     -0.029255 -1.008714 -0.398679       -0.416791      -0.954798
# 65551      5.634627 -0.396035 -0.398679       -0.007475      -0.585073
# 65552      4.501850 -0.702375 -0.398679       -0.286850      -0.803234
# 65553     -0.784439 -0.396035  0.515100       -0.299844      -0.415301
#
#        Prom.num.Neighbours  Densidad  Heterogeneidad  Nodos_aislados  \
# ...

# %% [markdown]
# # **c. Ahora si tenemos un mejor gráfico de los datos**

# %%
# **c. Ahora si tenemos un mejor gráfico de los datos**
plt.figure(figsize=(20,6))
data1.boxplot(grid=True,fontsize=5)
plt.legend(fontsize=16)
plt.yticks(fontsize=16)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **d. Construyamos los Histogramas para cada variable observadar**

# %%
# **d. Construyamos los Histogramas para cada variable observadar**
cols=data1.columns[1:-1]
N=len(cols)
plt.figure(figsize=(10,5))
plt.subplot(141)
sns.histplot(data1['diámetro'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(142)
sns.histplot(data1['Longitud_ruta'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(143)
sns.histplot(data1['Estrés_real'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(144)
sns.histplot(data1['Ingrado_real'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.show()

# %%
# **d. Construyamos los Histogramas para cada variable observadar**
cols=data1.columns[1:-1]
N=len(cols)
plt.figure(figsize=(10,5))
plt.subplot(141)
sns.histplot(data1['NumberOfUndirectedEdges'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(142)
sns.histplot(data1['CercaníaCentralidad'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(143)
sns.histplot(data1['nodeCount'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(144)
sns.histplot(data1['Ruta_más_corta'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.show()

# %%
# **d. Construyamos los Histogramas para cada variable observadar**
cols=data1.columns[1:-1]
N=len(cols)
plt.figure(figsize=(10,5))
plt.subplot(141)
sns.histplot(data1['Nodos_de_varios ejes'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(142)
sns.histplot(data1['Prom.num.Neighbours'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(143)
sns.histplot(data1['Heterogeneidad'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.subplot(144)
sns.histplot(data1['Conectividad_vecindario'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
plt.show()

# %% [markdown]
# # **139. Gráficas de densidad**
# + **Mostrando una curva de densidad**. Si bien histplot (y displot) pueden superponer una curva de densidad kernel sobre el histograma, distplot también puede mostrar solo la curva de densidad si el histograma está deshabilitado:
# + El siguiente tipo de gráfico es un gráfico de estimación de densidad kernel (KDE).
# + En caso de que no esté familiarizado con los gráficos de KDE, puede considerarlo como un histograma suavizado.
# + Para hacer un gráfico de KDE, usamos el comando sns.kdeplot. Establecer shade=True colorea el área debajo de la curva (y data= tiene la misma funcionalidad que cuando hicimos el histograma de arriba).

# %% [markdown]
# # **a. kdeplot con área para cada Variable**

# %%
# **a. kdeplot con área para cada Variable**
cols=data1.columns[1:-1]
N=len(cols)
plt.figure(figsize=(25,6))
plt.subplot(141)
sns.kdeplot(data1['diámetro'], shade=True)
plt.subplot(142)
sns.kdeplot(data1['Longitud_ruta'], shade=True)
plt.subplot(143)
sns.kdeplot(data1['Estrés_real'], shade=True)
plt.subplot(144)
sns.kdeplot(data1['Ingrado_real'], shade=True)
plt.show()

# %%
# **a. kdeplot con área para cada Variable**
cols=data1.columns[1:-1]
N=len(cols)
plt.figure(figsize=(25,6))
plt.subplot(141)
sns.kdeplot(data1['NumberOfUndirectedEdges'], shade=True)
plt.subplot(142)
sns.kdeplot(data1['CercaníaCentralidad'], shade=True)
plt.subplot(143)
sns.kdeplot(data1['nodeCount'], shade=True)
plt.subplot(144)
sns.kdeplot(data1['Ruta_más_corta'], shade=True)
plt.show()

# %% [markdown]
# # **b. Kernel Density Estimation (KDE) en Python**
# + Es similar al histograma, es un método no paramétrico que nos permite conocer la distribución de nuestros datos.
# + Nos proporciona una curva de densidad de probabilidad continua lo que nos permite interpretación mas facil cuando se incluyen las distribuciones de multiples variables en un solo grafico.
# +
#
# + No estamos restringidos a una sola columna al crear un diagrama de KDE.
# + Podemos crear un gráfico KDE bidimensional (2D) con el comando sns.jointplot. + En el diagrama a continuación, el código de colores nos muestra qué tan probable es que veamos diferentes combinaciones de ancho de sépalo y largo de pétalo, donde las partes más oscuras de la figura son más probables.

# %%
data1.columns
# Out:
# Index(['C_conectados', 'diámetro', 'radio', 'Ruta_más_corta', 'Longitud_ruta',
#        'Prom.num.Neighbours', 'Densidad', 'Heterogeneidad', 'Nodos_aislados',
#        'Self_Loops', 'Nodos_de_varios ejes', 'Conectividad_vecindario',
#        'NumberOfDirected', 'Estrés_real', 'SelfLoops', 'Partner', 'Grado real',
#        'EdgeCount', 'C_Topológico', 'BetweennessCentrality', 'Ingrado_real',
#        'Excentricidad_real', 'NumberOfUndirectedEdges', 'CercaníaCentralidad',
#        'Average', 'Coeficienteagrupamiento', 'nodeCount'],
#       dtype='object')

# %%
# **b. Gráficos KDE 2D**
plt.figure(figsize=(8,6))
sns.jointplot(x=data1['diámetro'], y=data1['Longitud_ruta'], kind="kde")
plt.show()

# %%
# **b. Gráficos KDE 2D**
plt.figure(figsize=(2,2))
sns.jointplot(x=data2['EdgeCount'], y=data2['C_Topológico'], kind="kde")
plt.show()

# %% [markdown]
# # **140. ¿Cuál es la mejor Distribución que se ajusta a los datos? - Libreria _fitter_**
# + https://medium.com/the-researchers-guide/finding-the-best-distribution-that-fits-your-data-using-pythons-fitter-library-319a5a0972e9

# %% [markdown]
# # **a. Recordemos nuestra base de datos**

# %%
# **a. Recordemos nuestra base de datos**
data1
# Out:
#        C_conectados  diámetro     radio  Ruta_más_corta  Longitud_ruta  \
# 0         -0.784439  3.280042  5.997776        1.207482       3.320007
# 1         -0.784439  0.829324  3.256438        0.674720       1.058305
# 2         -0.406847  1.135664 -0.398679        0.817656       0.955267
# 3          0.725929  0.216644 -0.398679       -0.137416       0.181935
# 4         -0.406847  0.216644 -0.398679       -0.072445       0.305758
# ...             ...       ...       ...             ...            ...
# 65549     -0.784439 -1.008714 -0.398679       -0.429786      -0.954798
# 65550     -0.029255 -1.008714 -0.398679       -0.416791      -0.954798
# 65551      5.634627 -0.396035 -0.398679       -0.007475      -0.585073
# 65552      4.501850 -0.702375 -0.398679       -0.286850      -0.803234
# 65553     -0.784439 -0.396035  0.515100       -0.299844      -0.415301
#
#        Prom.num.Neighbours  Densidad  Heterogeneidad  Nodos_aislados  \
# ...

# %% [markdown]
# # **b. Aplicación necesaria**

# %%
# **b. Aplicación necesaria**
# !pip install fitter
from fitter import Fitter, get_common_distributions, get_distributions

# %% [markdown]
# # **c. Escogemos una de nuestras variables**

# %%
# **c. Escogemos una de nuestras variables**
Lon_diam = data1['diámetro'].values
Lon_diam
# Out:
# array([ 3.28004169,  0.82932389,  1.13566362, ..., -0.39603501,
#        -0.70237474, -0.39603501])

# %% [markdown]
# # **d. Distribuciones de ajuste para _Lon_diam_**
# + El siguiente paso es comenzar a ajustar diferentes distribuciones y encontrar la distribución más adecuada para los datos.
#
# + Los pasos son:
#
# + + Cree una instancia de Fitter llamando a Fitter()
# + + Proporcione los datos (Lon_pet) y la lista de distribuciones si tiene una idea básica de las distribuciones que podrían ajustarse a sus datos
# + + Aplicar el método .fit( )
# + + Genere el resumen de distribución ajustado usando el método .summary()
#
# ## **Nota:**
#
# + La clase Fitter en el backend usa la biblioteca Scipy que admite 80 distribuciones y la clase Fitter las escaneará todas, llamará a la función de ajuste por usted, ignorará aquellas que fallan o se ejecutan para siempre y finalmente le brinda un resumen de las mejores distribuciones en el sentido de la suma de los cuadrados de los errores.
#
# + Pero esto puede llevar algo de tiempo, ya que probará muchas distribuciones y el tiempo de ajuste también varía según el tamaño de la muestra. Por lo tanto, se recomienda trazar primero un histograma y obtener una idea general sobre los tipos de distribuciones que podrían ajustarse a los datos y proporcionar esos nombres de distribución en una lista utilizando el argumento de distribuciones . Esto definitivamente le ahorrará tiempo.
#
# + Aquí, he ajustado las distribuciones **gamma**, **lognormal**, **beta**, **burr** y **normal**.
# + Llamar al método summary( ) en el objeto ajustado muestra las diferentes distribuciones y estadísticas de ajuste, como:
# + + sumsquare_error,
# + + el criterio de información de Akaike ( aic )
# + + y los valores del criterio de información bayesiano ( bic ).
# + De forma predeterminada, la función de resumen clasifica las cinco mejores distribuciones según los valores de sumsquare_error en orden ascendente. Además, proporciona una ilustración de diferentes distribuciones ajustadas sobre un histograma.
#
# ## **La distribución Burr**
# + (a veces llamada distribución Burr Tipo XII o distribución Singh-Maddala) es una familia unimodal de distribuciones con una amplia variedad de formas.
# + Esta distribución se utiliza para modelar una amplia variedad de fenómenos, incluidos los precios de los cultivos, los ingresos familiares, las distribuciones de precios del mercado de opciones, el riesgo (seguro) y el tiempo de viaje.
# + Es particularmente útil para modelar histogramas . Aunque existen otras formas (el tipo III también es muy común), el término “distribución de rebabas” suele referirse al tipo XII.
# + La distribución de rebabas Tipo XII se define por los siguientes parámetros:
# + + c y k: parámetros de forma . Para Burr Tipo XII, ambos son positivos. El tipo III tiene un parámetro c negativo.
# + + $\alpha$: parámetro de escala .
# + + $\gamma$: parámetro de ubicación continua .
# + Cuando el cuarto parámetro, $\gamma$, es igual a cero, da una distribución de tres parámetros ($c$,$k$,$\alpha$).

# %%
# **d. Distribuciones de ajuste para _Lon_pet_**
f = Fitter(Lon_diam,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
# Fitting 5 distributions: 100%|██████████| 5/5 [00:11<00:00,  2.21s/it]
#          sumsquare_error          aic            bic  kl_div  ks_statistic  \
# lognorm         3.397461  1034.669747 -646827.459194     inf      0.123991
# beta            3.867891  1392.968968 -638315.253610     inf      0.292508
# gamma           4.005059  1550.004435 -636041.852723     inf      0.292973
# burr            4.152145   908.320851 -633666.449611     inf      0.314561
# norm            4.336317  5233.309774 -630843.564515     inf      0.184300
#
#          ks_pvalue
# lognorm        0.0
# beta           0.0
# gamma          0.0
# burr           0.0
# norm           0.0

# %% [markdown]
# # **e. Identificando la mejor distribución**

# %%
# **e. Identificando la mejor distribución**
f.get_best(method = 'sumsquare_error')
# Out:
# {'lognorm': {'s': 0.9111765745895345,
#   'loc': -1.1723345870701882,
#   'scale': 0.8104367968181123}}

# %% [markdown]
# # **f. Con todas las Distribuciones de ajuste para _Lon_pet_**

# %%
# **f. Con todas las Distribuciones de ajuste para _Lon_pet_**
f = Fitter(Lon_diam,
           distributions=
['alfa', 'anglit', 'arcsine', 'argus', 'beta', 'betaprime', 
 'bradford', 'burr', 'burr12', 'cauchy', 'chi', 'chi2', ' coseno', 
 'bola de cristal', 'dgamma', 'dweibull', 'erlang', 'expon', 'exponnorm', 
 'exponpow', 'exponweib', 'f', 'fatiguelife', 'fisk', 'foldcauchy' , 
 'foldnorm', 'frechet_l', 'frechet_r', 'gamma', 'gausshyper', 'genexpon', 
 'genextreme', 'gengamma', 'genhalflogistic', 'geninvgauss', 'genlogistic',
 'gennorm', ' genpareto', 'gilbrat', 'gompertz', 'gumbel_l', 'gumbel_r', 
 'halfcauchy', 'halfgennorm', 'halflogistic', 'halfnorm',
'hypsecant', 'invgamma', 'invgauss', 'invweibull', 'johnsonsb', 'johnsonsu', 
 'kappa3', 'kappa4', 'ksone', 'kstwo', 'kstwobign', 'laplace', 'levy ', 'levy_l', 
 'levy_stable', 'loggamma', 'logística', 'loglaplace', 'lognorm', 'louniform', 
 'lomax', 'maxwell', 'mielke', 'moyal', 'nakagami', 'ncf', 'nct', 'ncx2',
'norma', 'norminvgauss', 'pareto', 'pearson3', 'powerlaw', 'powerlognorm', 
 'powernorm', 'rayleigh', 'rdist', 'recipinvgauss ', 'recíproco', 'arroz', 
 'rv_continuo', 'rv_histograma', 'semicircular', 'skewnorm', 't', 'trapz', 
 'triang', 'truncexpon', 'truncnorm', 'tukeylambda', 'uniforme', 'vonmises', 
 'vonmises_line', 'wald', 'weibull_max', 'weibull_min', 'wrapcauchy'])
f.fit()
f.summary()
# Out:
# ...
# Fitting 103 distributions:  58%|█████▊    | 60/103 [04:52<04:00,  5.58s/it]WARNING:fitter.fitter:SKIPPED levy_stable distribution (taking more than 30 seconds)
# WARNING:fitter.fitter:SKIPPED logística distribution (taking more than 30 seconds)
# ...
# Fitting 103 distributions:  70%|██████▉   | 72/103 [06:26<06:37, 12.83s/it]WARNING:fitter.fitter:SKIPPED nct distribution (taking more than 30 seconds)
# WARNING:fitter.fitter:SKIPPED norma distribution (taking more than 30 seconds)
# ...
# Fitting 103 distributions:  81%|████████  | 83/103 [07:39<02:22,  7.11s/it]WARNING:fitter.fitter:SKIPPED arroz distribution (taking more than 30 seconds)
# WARNING:fitter.fitter:SKIPPED rv_continuo distribution (taking more than 30 seconds)
# WARNING:fitter.fitter:SKIPPED rv_histograma distribution (taking more than 30 seconds)
# ...
# Fitting 103 distributions: 100%|██████████| 103/103 [09:42<00:00,  5.66s/it]
#             sumsquare_error          aic            bic  kl_div  ks_statistic  \
# ...

# %% [markdown]
# # **g. Identificando la mejor distribución**

# %%
# **g. Identificando la mejor distribución**
f.get_best(method = 'sumsquare_error')
# Out:
# {'genexpon': {'a': 17.10055701815125,
#   'b': 10.454867000572614,
#   'c': 0.2153571816708758,
#   'loc': -1.0087144603658391,
#   'scale': 17.37883328257361}}
