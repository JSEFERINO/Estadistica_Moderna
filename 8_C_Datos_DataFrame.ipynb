# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/C_Datos/blob/main/8_C_Datos_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso Introductorio a la Ciencia de Datos por Julio Hurtado Márquez**
# ## **Parte I**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #**34. Creando un dataFrame usando arrays**
# ##**a. Construyamos una matriz que contenga el día y fecha de cumpleaños de mi familia**

# %%
# Creando un array
data = np.array([[2,6], [9,25], [3,21], [7,21], [12,10], [9,21]])
data
# Out:
# array([[ 2,  6],
#        [ 9, 25],
#        [ 3, 21],
#        [ 7, 21],
#        [12, 10],
#        [ 9, 21]])

# %% [markdown]
# ## **b. Creamos el DataFrame**

# %%
#Creando un data Frame
pd.DataFrame(data)
# Out:
#     0   1
# 0   2   6
# 1   9  25
# 2   3  21
# 3   7  21
# 4  12  10
# 5   9  21

# %% [markdown]
# ## **c. Las Filas son los membros de la Familia y el mes de cumpleaños**

# %%
#Creando un data Frame
fh = pd.DataFrame(data, index = ["Julio", "Marelis", "Aris", "Dayana", "Cofy", "Chiqui"], columns= ["Mes","Dia"])
fh
# Out:
#          Mes  Dia
# Julio      2    6
# Marelis    9   25
# Aris       3   21
# Dayana     7   21
# Cofy      12   10
# Chiqui     9   21

# %% [markdown]
# #**35. Creando un DataFrame en Python usando lista**

# %% [markdown]
# ## **a. Creamos una lista con cumpleaños**

# %%
# **a. Creamos una lista con cumpleaños**
cumpleaños3 = [[2,6], [9,25], [3,21], [7,21], [12,10], [9,21]]
cumpleaños3
# Out:
# [[2, 6], [9, 25], [3, 21], [7, 21], [12, 10], [9, 21]]

# %% [markdown]
# ## **b. Creando un data Frame de la misma forma que en el caso 1**

# %%
## **Creando un data Frame**
fh2 = pd.DataFrame(cumpleaños3, index = ["Julio", "Marelis", "Aris", "Dayana", "Cofy", "Chiqui"], columns= ["Mes","Dia"])
fh2
# Out:
#          Mes  Dia
# Julio      2    6
# Marelis    9   25
# Aris       3   21
# Dayana     7   21
# Cofy      12   10
# Chiqui     9   21

# %% [markdown]
# ## **c. Cree un DataFrame en Python con los nombres de los departamentos y sus capitaes**

# %%
# **c. Creando la lista**
costa = [["Guajira","RioHacha"], ["Magdalena","Santa Marta"], ["Cesár","Valledupar"], ["Atlántico","Barranquilla"], ["Bolivar","Cartagena"], ["Sucre","Sincelejo"], ["Córdova", "Montería"]]

# %%
#Creando un data Frame
C_Caribe = pd.DataFrame(costa, index = ["region1", "region2", "region3", "region4", "region5", "region6", "region7"], columns= ["Dpto","Capital"])
C_Caribe
# Out:
#               Dpto       Capital
# region1    Guajira      RioHacha
# region2  Magdalena   Santa Marta
# region3      Cesár    Valledupar
# region4  Atlántico  Barranquilla
# region5    Bolivar     Cartagena
# region6      Sucre     Sincelejo
# region7    Córdova      Montería

# %% [markdown]
# #**35. Creando un DataFrame en Python usando diccionarios**

# %% [markdown]
# ## **a. Creando las listas de las ciudades y dptos**

# %%
ciudad_3 = ['Cartagena', 'Barranquilla', 'Santa Marta', 'Montería', 'Sincelejo', 'Valledupar', 'Riohacha']

# %%
dpto4 = ['Bolívar', 'Atlántico', 'Magdalena', 'Córdoba', 'Sucre', 'Cesar', 'Guajira']

# %% [markdown]
# ## **b. Creando los diccionarios**

# %%
## **b. Creando los diccionarios**
dic_Dptos = {"Ciudad": ciudad_3, "Departamento":dpto4}

# %% [markdown]
# ## **c. Creando el DataFrame con los diccionarios**

# %%
## **c. Creando el DataFrame con los diccionarios**
dic_ciudad = pd.DataFrame(dic_Dptos)
dic_ciudad
# Out:
#          Ciudad Departamento
# 0     Cartagena      Bolívar
# 1  Barranquilla    Atlántico
# 2   Santa Marta    Magdalena
# 3      Montería      Córdoba
# 4     Sincelejo        Sucre
# 5    Valledupar        Cesar
# 6      Riohacha      Guajira

# %% [markdown]
# #**36. Crear un DataFrame usando archivos csv**
# ##**a. Subiendo un archivo csv a Python**

# %%
import cv2 as cv
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-cf9c38bf-4103-4808-82e9-9e24f0e0effc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf9c38bf-4103-4808-82e9-9e24f0e0effc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **b. Construimos el DataFrame con el archivo excel**

# %%
# **b. Construimos el DataFrame con el archivo excel**
df_datos2023 = pd.read_csv("/content/DATOS2023py.csv", delimiter=';')
df_datos2023
# Out:
#              CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  \
# 0    ESTADISTICA I        4,3     COMS    18     SI    55       164
# 1    ESTADISTICA I        3,1     COMS    19     SI    65       165
# 2    ESTADISTICA I        4,2     DERH    25     NO    56       170
# 3    ESTADISTICA I        3,6     DERH    23     SI    65       170
# 4    ESTADISTICA I        3,9     PSIC    19     SI    50       169
# ..             ...        ...      ...   ...    ...   ...       ...
# 116  ESTADISTICA I        3,5     PSIC    18     SI    60       163
# 117  ESTADISTICA I        3,5     PSIC    18     SI    60       180
# 118  ESTADISTICA I        2,5     COMS    21     NO    45       172
# 119  ESTADISTICA I          3     COMS    20     NO    50       160
# 120  ESTADISTICA I        3,5     DERH    21     NO    57       160
#
#      SATISFACC  SABER 11 PROMEDIO SEXO ESTRATO Herramientas
# 0            4       350     4,26    F      II         PTWF
# ...

# %% [markdown]
# ## **c. Renombramos el archivo para mejorarlo**

# %%
df_datos = df_datos2023
df_datos
# Out:
#              CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  \
# 0    ESTADISTICA I        4,3     COMS    18     SI    55       164
# 1    ESTADISTICA I        3,1     COMS    19     SI    65       165
# 2    ESTADISTICA I        4,2     DERH    25     NO    56       170
# 3    ESTADISTICA I        3,6     DERH    23     SI    65       170
# 4    ESTADISTICA I        3,9     PSIC    19     SI    50       169
# ..             ...        ...      ...   ...    ...   ...       ...
# 116  ESTADISTICA I        3,5     PSIC    18     SI    60       163
# 117  ESTADISTICA I        3,5     PSIC    18     SI    60       180
# 118  ESTADISTICA I        2,5     COMS    21     NO    45       172
# 119  ESTADISTICA I          3     COMS    20     NO    50       160
# 120  ESTADISTICA I        3,5     DERH    21     NO    57       160
#
#      SATISFACC  SABER 11 PROMEDIO SEXO ESTRATO Herramientas
# 0            4       350     4,26    F      II         PTWF
# ...

# %% [markdown]
# ## **d. Mostramos las primeras cinco filas del archivo**

# %%
## **d. Mostramos las primeras cinco filas del archivo**
df_datos.head()
# Out:
#            CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  SATISFACC  \
# 0  ESTADISTICA I        4,3     COMS    18     SI    55       164          4
# 1  ESTADISTICA I        3,1     COMS    19     SI    65       165          5
# 2  ESTADISTICA I        4,2     DERH    25     NO    56       170          5
# 3  ESTADISTICA I        3,6     DERH    23     SI    65       170          5
# 4  ESTADISTICA I        3,9     PSIC    19     SI    50       169          5
#
#    SABER 11 PROMEDIO SEXO ESTRATO Herramientas
# 0       350     4,26    F      II         PTWF
# 1       328     4,11    F       I         CYDT
# 2       285      3,7    M       I         CYDT
# 3       280      4,1    F      II         PCWF
# 4       319        4    F      II         CYWF

# %% [markdown]
# ## **e. Mostramos las ultimas cinco filas del DataFrame**

# %%
## **e. Mostramos las ultimas cinco filas del DataFrame**
df_datos.tail()
# Out:
#              CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  \
# 116  ESTADISTICA I        3,5     PSIC    18     SI    60       163
# 117  ESTADISTICA I        3,5     PSIC    18     SI    60       180
# 118  ESTADISTICA I        2,5     COMS    21     NO    45       172
# 119  ESTADISTICA I          3     COMS    20     NO    50       160
# 120  ESTADISTICA I        3,5     DERH    21     NO    57       160
#
#      SATISFACC  SABER 11 PROMEDIO SEXO ESTRATO Herramientas
# 116          5       310      3,9    F     III         PTWF
# 117          3       346      3,9    M      IV         PCWF
# 118          5       221      3,7    F      II         CYWF
# 119          4       332      3,5    F      II         CYDT
# 120          4       293      3,5    F     III         PTWF

# %%
## **f. Mostramos las primeras 10 filas del DataFrame**
df_datos.head(10)
# Out:
#            CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  SATISFACC  \
# 0  ESTADISTICA I        4,3     COMS    18     SI    55       164          4
# 1  ESTADISTICA I        3,1     COMS    19     SI    65       165          5
# 2  ESTADISTICA I        4,2     DERH    25     NO    56       170          5
# 3  ESTADISTICA I        3,6     DERH    23     SI    65       170          5
# 4  ESTADISTICA I        3,9     PSIC    19     SI    50       169          5
# 5  ESTADISTICA I        1,1     PSIC    19     SI    68       165          4
# 6  ESTADISTICA I        3,5    CIENP    19     SI    86       184          5
# 7  ESTADISTICA I        4,2    CIENP    19     NO    53       163          5
# 8  PROBABILIDAD         4,4     ININ    18     NO    56       158          5
# 9  PROBABILIDAD         4,1     INMT    20     SI    72       179          4
#
#    SABER 11 PROMEDIO SEXO ESTRATO Herramientas
# 0       350     4,26    F      II         PTWF
# ...

# %% [markdown]
# ## **g. Mostramos las últimas 10 filas del DataFrame**

# %%
## **g. Mostramos las últimas 10 filas del DataFrame**
df_datos.tail(10)
# Out:
#              CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  \
# 111  ESTADISTICA I        1,5     COMS    19     SI    61       156
# 112  ESTADISTICA I        3,5     COMS    19     SI    66       110
# 113  ESTADISTICA I        4,5     PSIC    18     SI    60       180
# 114  ESTADISTICA I          4     PSIC    18     NO    47       155
# 115  ESTADISTICA I        2,5     PSIC    21     SI    70       185
# 116  ESTADISTICA I        3,5     PSIC    18     SI    60       163
# 117  ESTADISTICA I        3,5     PSIC    18     SI    60       180
# 118  ESTADISTICA I        2,5     COMS    21     NO    45       172
# 119  ESTADISTICA I          3     COMS    20     NO    50       160
# 120  ESTADISTICA I        3,5     DERH    21     NO    57       160
#
#      SATISFACC  SABER 11 PROMEDIO SEXO ESTRATO Herramientas
# 111          5       238      3,5    F     III         PTWF
# 112          4       255       40    M     III         PCWF
# ...

# %% [markdown]
# # **37. Atributos y Métodos del DataFrame**

# %% [markdown]
# #**a. Mostrar todas las filas del DataFrame**

# %%
#**a. Mostrar todas las filas del DataFrame**
pd.set_option("display.max_rows",121)
df_datos
# Out:
#              CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  \
# 0    ESTADISTICA I        4,3     COMS    18     SI    55       164
# 1    ESTADISTICA I        3,1     COMS    19     SI    65       165
# 2    ESTADISTICA I        4,2     DERH    25     NO    56       170
# 3    ESTADISTICA I        3,6     DERH    23     SI    65       170
# 4    ESTADISTICA I        3,9     PSIC    19     SI    50       169
# 5    ESTADISTICA I        1,1     PSIC    19     SI    68       165
# 6    ESTADISTICA I        3,5    CIENP    19     SI    86       184
# 7    ESTADISTICA I        4,2    CIENP    19     NO    53       163
# 8    PROBABILIDAD         4,4     ININ    18     NO    56       158
# 9    PROBABILIDAD         4,1     INMT    20     SI    72       179
# 10   PROBABILIDAD         4,8     INNV    18     SI    64       175
# 11   PROBABILIDAD         4,5     ININ    17     NO    75       177
# 12   PROBABILIDAD         3,9     INQU    19     SI    61       158
# ...

# %% [markdown]
# ## **b. Accediendo al atributo shape, el cual me muestra la cantidad de filas y columnas**

# %%
# **b. Accediendo al atributo shape, el cual me muestra la cantidad de filas y columnas**
df_datos.shape
# Out:
# (121, 13)

# %% [markdown]
# ## **c. El Atributo index muestra la misma información**

# %%
# **c. El Atributo index muestra la misma información**
df_datos.index
# Out:
# RangeIndex(start=0, stop=121, step=1)

# %% [markdown]
# ## **d. El Atributo _columns_ muestra el nombre de las variables**

# %%
## **d. El Atributo -columns- muestra el nombre de las variables**
df_datos.columns
# Out:
# Index(['CURSO', 'DEFINITIVA', 'PROGRAMA', 'EDAD', 'URBANO', 'PESO', 'ESTATURA',
#        'SATISFACC', 'SABER 11', 'PROMEDIO', 'SEXO', 'ESTRATO', 'Herramientas'],
#       dtype='object')

# %% [markdown]
# ## **e. El Atributo _dtypes_ muestra el tipo de las  variables**
# ### **Algunas variables numéricas aparecen como categoricas, dado que les aparece ',' en lugar de '.'**

# %%
## **e. El Atributo _dtypes_ muestra el tipo de las  variables**
### **Algunas variables numéricas aparecen como categoricas, dado que les aparece ',' en lugar de '.'**
df_datos.dtypes
# Out:
# CURSO           object
# DEFINITIVA      object
# PROGRAMA        object
# EDAD             int64
# URBANO          object
# PESO             int64
# ESTATURA         int64
# SATISFACC        int64
# SABER 11         int64
# PROMEDIO        object
# SEXO            object
# ESTRATO         object
# Herramientas    object
# dtype: object

# %% [markdown]
# #**38. Métodos usados para DataFrame**

# %% [markdown]
# ## **a. El Método _info()_ muestra el tipo de las  variables en un DataFrame**
# ### **Algunas variables numéricas aparecen como categoricas, dado que les aparece ',' en lugar de '.'**

# %%
## **a. El Método _info()_ muestra el tipo de las  variables en un DataFrame**
### **Algunas variables numéricas aparecen como categoricas, dado que les aparece ',' en lugar de '.'**
df_datos.info() # La variable DEFINITIVA aparece como cadena porque usa (,)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CURSO         121 non-null    object
#  1   DEFINITIVA    121 non-null    object
#  2   PROGRAMA      121 non-null    object
#  3   EDAD          121 non-null    int64
#  4   URBANO        121 non-null    object
#  5   PESO          121 non-null    int64
#  6   ESTATURA      121 non-null    int64
#  7   SATISFACC     121 non-null    int64
#  8   SABER 11      121 non-null    int64
#  9   PROMEDIO      121 non-null    object
#  10  SEXO          121 non-null    object
#  11  ESTRATO       120 non-null    object
#  12  Herramientas  121 non-null    object
# dtypes: int64(5), object(8)
# memory usage: 12.4+ KB

# %% [markdown]
# ## **b. El Método _describe()_ muestra los estadisticos  concalculado las  variables en un DataFrame**
# ### **Mostrando analisis descriptivos de la información del DataFrame**

# %%
## **b. El Método _describe()_ muestra los estadisticos  concalculado las  variables en un DataFrame**
### **Mostrando analisis descriptivos de la información del DataFrame**
df_datos.describe() # No aparece la variable DEFINITIVA
# Out:
#              EDAD        PESO    ESTATURA  SATISFACC    SABER 11
# count  121.000000  121.000000  121.000000  121.00000  121.000000
# mean    18.553719   63.239669  167.933884    4.53719  305.429752
# std      1.653030   12.935755   12.369812    0.63300   43.059228
# min     16.000000   37.000000  100.000000    3.00000  204.000000
# 25%     18.000000   55.000000  163.000000    4.00000  275.000000
# 50%     18.000000   61.000000  169.000000    5.00000  305.000000
# 75%     19.000000   73.000000  175.000000    5.00000  341.000000
# max     27.000000   97.000000  192.000000    5.00000  380.000000

# %% [markdown]
# ## **c. El Método _str.replace()_ permite reemplazar en las variables aquellas que aparecen con comas**
# ### **Cambiar la coma (,) por punto (.)**

# %%
## **c. El Método _str.replace()_ permite reemplazar (.) en las variables aquellas que aparecen con comas (,)**
### **Cambiar la coma (,) por punto (.)**
df_datos["DEFINITIVA"]=df_datos["DEFINITIVA"].str.replace(",",".")
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].str.replace(",",".")
df_datos.head()
# Out:
#            CURSO DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  SATISFACC  \
# 0  ESTADISTICA I        4.3     COMS    18     SI    55       164          4
# 1  ESTADISTICA I        3.1     COMS    19     SI    65       165          5
# 2  ESTADISTICA I        4.2     DERH    25     NO    56       170          5
# 3  ESTADISTICA I        3.6     DERH    23     SI    65       170          5
# 4  ESTADISTICA I        3.9     PSIC    19     SI    50       169          5
#
#    SABER 11 PROMEDIO SEXO ESTRATO Herramientas
# 0       350     4.26    F      II         PTWF
# 1       328     4.11    F       I         CYDT
# 2       285      3.7    M       I         CYDT
# 3       280      4.1    F      II         PCWF
# 4       319        4    F      II         CYWF

# %% [markdown]
# ## **d. Revisamos nuevamente con _info()_ Aun la variable DEFINITIVA  y PROMEDIO aparecen como OBJECT**

# %%
## **d. Revisamos nuevamente con _info()_ Aun la variable DEFINITIVA  y PROMEDIO aparecen como OBJECT
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CURSO         121 non-null    object
#  1   DEFINITIVA    121 non-null    object
#  2   PROGRAMA      121 non-null    object
#  3   EDAD          121 non-null    int64
#  4   URBANO        121 non-null    object
#  5   PESO          121 non-null    int64
#  6   ESTATURA      121 non-null    int64
#  7   SATISFACC     121 non-null    int64
#  8   SABER 11      121 non-null    int64
#  9   PROMEDIO      121 non-null    object
#  10  SEXO          121 non-null    object
#  11  ESTRATO       120 non-null    object
#  12  Herramientas  121 non-null    object
# dtypes: int64(5), object(8)
# memory usage: 12.4+ KB

# %% [markdown]
# ## **e. Mostrando analisis descriptivos de la información del DataFrame**

# %%
## **e. Mostrando analisis descriptivos de la información del DataFrame**
df_datos.describe()
# Out:
#              EDAD        PESO    ESTATURA  SATISFACC    SABER 11
# count  121.000000  121.000000  121.000000  121.00000  121.000000
# mean    18.553719   63.239669  167.933884    4.53719  305.429752
# std      1.653030   12.935755   12.369812    0.63300   43.059228
# min     16.000000   37.000000  100.000000    3.00000  204.000000
# 25%     18.000000   55.000000  163.000000    4.00000  275.000000
# 50%     18.000000   61.000000  169.000000    5.00000  305.000000
# 75%     19.000000   73.000000  175.000000    5.00000  341.000000
# max     27.000000   97.000000  192.000000    5.00000  380.000000

# %% [markdown]
# #**39. Cambiando de OBJETO A NUMERICO en el DataFrame**

# %% [markdown]
# ## **a. Usando el método _astype()_ hacemos el cambio de tipo de variables**

# %%
## **a. Usando el método _astype()_ hacemos el cambio de tipo de variables**
df_datos["DEFINITIVA"]=df_datos["DEFINITIVA"].astype(np.float64)
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].astype(np.float64)

# %% [markdown]
# ## **b. Revisamos nuevamente con _info()_ Aun la variable DEFINITIVA  y PROMEDIO aparecen como OBJECT**

# %%
## **b. Revisamos nuevamente con _info()_ Aun la variable DEFINITIVA  y PROMEDIO aparecen como OBJECT
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CURSO         121 non-null    object
#  1   DEFINITIVA    121 non-null    float64
#  2   PROGRAMA      121 non-null    object
#  3   EDAD          121 non-null    int64
#  4   URBANO        121 non-null    object
#  5   PESO          121 non-null    int64
#  6   ESTATURA      121 non-null    int64
#  7   SATISFACC     121 non-null    int64
#  8   SABER 11      121 non-null    int64
#  9   PROMEDIO      121 non-null    float64
#  10  SEXO          121 non-null    object
#  11  ESTRATO       120 non-null    object
#  12  Herramientas  121 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 12.4+ KB

# %% [markdown]
# ## **c. Mostrando analisis descriptivos de la información del DataFrame**
# ### _Al parecer hay algunos datos herrados en la Variable PROMEDIO__

# %%
## **c. Mostrando analisis descriptivos de la información del DataFrame**
df_datos.describe()
# Out:
#        DEFINITIVA        EDAD        PESO    ESTATURA  SATISFACC    SABER 11  \
# count  121.000000  121.000000  121.000000  121.000000  121.00000  121.000000
# mean     3.773554   18.553719   63.239669  167.933884    4.53719  305.429752
# std      0.863980    1.653030   12.935755   12.369812    0.63300   43.059228
# min      1.100000   16.000000   37.000000  100.000000    3.00000  204.000000
# 25%      3.500000   18.000000   55.000000  163.000000    4.00000  275.000000
# 50%      4.000000   18.000000   61.000000  169.000000    5.00000  305.000000
# 75%      4.500000   19.000000   73.000000  175.000000    5.00000  341.000000
# max      5.000000   27.000000   97.000000  192.000000    5.00000  380.000000
#
#          PROMEDIO
# count  121.000000
# mean     8.231901
# std     34.015054
# min      3.200000
# 25%      3.800000
# 50%      4.010000
# 75%      4.300000
# max    373.000000

# %% [markdown]
# ## **d. Con la función _len()_ tambien podemos explorar el tamaño del Data Frame**

# %%
## **d. Con la función _len()_ tambien podemos explorar el tamaño del Data Frame**
len(df_datos) # numero de filas
# Out:
# 121

# %% [markdown]
# ## **e. La función _max_ y el atributo _index_ podemos visualizar el máximo en cada variable**

# %%
## **e. La función _max_ y el atributo _index_ podemos visualizar el máximo en cada variable**
max(df_datos.index)
# Out:
# 120

# %% [markdown]
# ## **f. La función _min_ y el atributo _index_ podemos visualizar el mínimo**

# %%
## **f. La función _min_ y el atributo _index_ podemos visualizar el mínimo**
min(df_datos.index)
# Out:
# 0

# %% [markdown]
# ## **g. La función _type_  la clase del DataFrame**

# %%
## **g. La función _type_  la clase del DataFrame**
type(df_datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **h. La función _round_  podemos redondear en el DataFrame**

# %%
## **h. La función _round_  podemos redondear en el DataFrame**
round(df_datos,1)
# Out:
#              CURSO  DEFINITIVA PROGRAMA  EDAD URBANO  PESO  ESTATURA  \
# 0    ESTADISTICA I         4.3     COMS    18     SI    55       164
# 1    ESTADISTICA I         3.1     COMS    19     SI    65       165
# 2    ESTADISTICA I         4.2     DERH    25     NO    56       170
# 3    ESTADISTICA I         3.6     DERH    23     SI    65       170
# 4    ESTADISTICA I         3.9     PSIC    19     SI    50       169
# 5    ESTADISTICA I         1.1     PSIC    19     SI    68       165
# 6    ESTADISTICA I         3.5    CIENP    19     SI    86       184
# 7    ESTADISTICA I         4.2    CIENP    19     NO    53       163
# 8    PROBABILIDAD          4.4     ININ    18     NO    56       158
# 9    PROBABILIDAD          4.1     INMT    20     SI    72       179
# 10   PROBABILIDAD          4.8     INNV    18     SI    64       175
# 11   PROBABILIDAD          4.5     ININ    17     NO    75       177
# 12   PROBABILIDAD          3.9     INQU    19     SI    61       158
# ...

# %% [markdown]
# #**40. Seleccionar una columna en el DataFrame para analizar los problemas**

# %%
## **a. Revisando la columna PROMEDIO**
df_datos["PROMEDIO"]
# Out:
# 0        4.26
# 1        4.11
# 2        3.70
# 3        4.10
# 4        4.00
# 5        3.70
# 6        4.48
# 7        3.70
# 8        3.80
# 9        3.90
# 10       4.69
# 11       4.69
# 12       3.77
# 13       3.77
# 14       4.30
# 15       3.80
# 16       4.48
# 17       3.79
# 18       4.00
# 19       3.90
# 20       3.90
# 21       3.86
# 22       4.31
# 23       4.02
# 24       4.22
# 25       3.82
# 26     373.00
# 27      37.00
# 28       4.01
# 29       3.78
# 30       4.12
# 31       3.80
# 32       3.81
# 33       3.90
# 34       4.10
# 35       4.30
# 36       4.03
# 37       4.08
# 38       4.26
# 39       3.70
# 40       4.20
# 41       3.90
# 42       4.03
# 43       4.00
# 44       3.87
# 45       4.22
# 46       3.73
# 47       3.88
# 48       3.80
# 49       4.00
# 50       4.68
# 51       4.10
# 52       4.01
# 53       4.33
# 54      42.60
# 55       4.10
# 56       3.90
# 57       4.10
# 58       4.30
# 59       4.20
# 60       4.20
# 61       4.46
# ...

# %% [markdown]
# ## **b. La Variable PROMEDIO tiene errores en la entrada**
# |||
# |:--:|:--:|
# |26|     373.00|
# |27|      37.00|
# |54|      42.60|
# |100|     35.00|
# |112|     40.00|

# %% [markdown]
# ## **c. Realizamos las correcciones pertinenetes en la Variable PROMEDIO**

# %%
## **c. Realizamos las correcciones pertinenetes en la Variable PROMEDIO**
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].replace(40.00,4.0)
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].replace(35.00,3.5)
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].replace(42.00,4.2)
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].replace(37.00,3.7)
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].replace(373.00,3.7)
df_datos["PROMEDIO"]=df_datos["PROMEDIO"].replace(42.60,4.3)
df_datos["PROMEDIO"]
# Out:
# 0      4.26
# 1      4.11
# 2      3.70
# 3      4.10
# 4      4.00
# 5      3.70
# 6      4.48
# 7      3.70
# 8      3.80
# 9      3.90
# 10     4.69
# 11     4.69
# 12     3.77
# 13     3.77
# 14     4.30
# 15     3.80
# 16     4.48
# 17     3.79
# 18     4.00
# 19     3.90
# 20     3.90
# 21     3.86
# 22     4.31
# 23     4.02
# 24     4.22
# 25     3.82
# 26     3.70
# 27     3.70
# 28     4.01
# 29     3.78
# 30     4.12
# 31     3.80
# 32     3.81
# 33     3.90
# 34     4.10
# 35     4.30
# 36     4.03
# 37     4.08
# 38     4.26
# 39     3.70
# 40     4.20
# 41     3.90
# 42     4.03
# 43     4.00
# 44     3.87
# 45     4.22
# 46     3.73
# 47     3.88
# 48     3.80
# 49     4.00
# 50     4.68
# 51     4.10
# 52     4.01
# 53     4.33
# 54     4.30
# 55     4.10
# 56     3.90
# 57     4.10
# 58     4.30
# 59     4.20
# 60     4.20
# 61     4.46
# 62     3.60
# 63     4.20
# 64     4.01
# 65     4.57
# 66     4.30
# 67     3.79
# 68     4.01
# 69     4.60
# 70     4.40
# ...

# %% [markdown]
# ## **d. Nuevamente redondeamos y nos concentramos en la variable PROMEDIO**

# %%
## **d. Nuevamente redondeamos y nos concentramos en la variable PROMEDIO**
round(df_datos["PROMEDIO"],1)
# Out:
# 0      4.3
# 1      4.1
# 2      3.7
# 3      4.1
# 4      4.0
# 5      3.7
# 6      4.5
# 7      3.7
# 8      3.8
# 9      3.9
# 10     4.7
# 11     4.7
# 12     3.8
# 13     3.8
# 14     4.3
# 15     3.8
# 16     4.5
# 17     3.8
# 18     4.0
# 19     3.9
# 20     3.9
# 21     3.9
# 22     4.3
# 23     4.0
# 24     4.2
# 25     3.8
# 26     3.7
# 27     3.7
# 28     4.0
# 29     3.8
# 30     4.1
# 31     3.8
# 32     3.8
# 33     3.9
# 34     4.1
# 35     4.3
# 36     4.0
# 37     4.1
# 38     4.3
# 39     3.7
# 40     4.2
# 41     3.9
# 42     4.0
# 43     4.0
# 44     3.9
# 45     4.2
# 46     3.7
# 47     3.9
# 48     3.8
# 49     4.0
# 50     4.7
# 51     4.1
# 52     4.0
# 53     4.3
# 54     4.3
# 55     4.1
# 56     3.9
# 57     4.1
# 58     4.3
# 59     4.2
# 60     4.2
# 61     4.5
# 62     3.6
# 63     4.2
# 64     4.0
# 65     4.6
# 66     4.3
# 67     3.8
# 68     4.0
# 69     4.6
# 70     4.4
# 71     4.1
# 72     4.5
# 73     4.0
# 74     4.2
# 75     4.4
# ...

# %% [markdown]
# #**e. Seleccionar dos o mas columnas en el DataFrame**

# %%
#**e. Seleccionar dos o mas columnas en el DataFrame**
df_datos[["PESO", "ESTATURA"]].head()
# Out:
#    PESO  ESTATURA
# 0    55       164
# 1    65       165
# 2    56       170
# 3    65       170
# 4    50       169

# %% [markdown]
# #**f. Seleccionar dos o mas columnas en el DataFrame**

# %%
#**f. Seleccionar dos o mas columnas en el DataFrame**
df_datos[["SEXO", "PESO", "ESTATURA"]].head()
# Out:
#   SEXO  PESO  ESTATURA
# 0    F    55       164
# 1    F    65       165
# 2    M    56       170
# 3    F    65       170
# 4    F    50       169

# %% [markdown]
# # **41. Exportar dataframes limpios**

# %%
# **41. Exportar dataframes limpios**
df_datos.to_csv('df_datos_LIMPIOS.csv',index=False)
